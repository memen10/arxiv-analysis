# %%
import arxiv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import word_tokenize
# from nltk.corpus import stopwords
import re
from string import punctuation
from wordcloud import WordCloud, STOPWORDS

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/diyosko7/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/diyosko7/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

# %% [markdown]
# ## Arxiv データ取得（Title に "semiconductor" が含まれるものを抽出）

# %%
papers = arxiv.query(
                        query="ti:semiconductor", 
                        max_results=None,
                        sort_by="submittedDate"
                        )
# Out:
# 2020-05-06 05:01:21,376 : INFO : max_results defaulting to inf.
# 2020-05-06 05:01:21,378 : INFO : Start downloading
# 2020-05-06 05:01:21,380 : INFO : Fetch from arxiv (inf results left to download)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2848: DeprecationWarning: urllib.parse.splittype() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   urltype, rest = urllib.parse.splittype(url_file_stream_or_string)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2849: DeprecationWarning: urllib.parse.splithost() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   realhost, rest = urllib.parse.splithost(rest)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2851: DeprecationWarning: urllib.parse.splituser() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   user_passwd, realhost = urllib.parse.splituser(realhost)
# 2020-05-06 05:01:33,524 : INFO : Received 1000 entries
# 2020-05-06 05:01:33,558 : INFO : Fetch from arxiv (inf results left to download)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2848: DeprecationWarning: urllib.parse.splittype() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   urltype, rest = urllib.parse.splittype(url_file_stream_or_string)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2849: DeprecationWarning: urllib.parse.splithost() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   realhost, rest = urllib.parse.splithost(rest)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2851: DeprecationWarning: urllib.parse.splituser() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   user_passwd, realhost = urllib.parse.splituser(realhost)
# 2020-05-06 05:01:47,847 : INFO : Received 1000 entries
# 2020-05-06 05:01:47,874 : INFO : Fetch from arxiv (inf results left to download)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2848: DeprecationWarning: urllib.parse.splittype() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   urltype, rest = urllib.parse.splittype(url_file_stream_or_string)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2849: DeprecationWarning: urllib.parse.splithost() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   realhost, rest = urllib.parse.splithost(rest)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2851: DeprecationWarning: urllib.parse.splituser() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   user_passwd, realhost = urllib.parse.splituser(realhost)
# 2020-05-06 05:01:59,602 : INFO : Received 1000 entries
# 2020-05-06 05:01:59,632 : INFO : Fetch from arxiv (inf results left to download)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2848: DeprecationWarning: urllib.parse.splittype() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   urltype, rest = urllib.parse.splittype(url_file_stream_or_string)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2849: DeprecationWarning: urllib.parse.splithost() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   realhost, rest = urllib.parse.splithost(rest)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2851: DeprecationWarning: urllib.parse.splituser() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   user_passwd, realhost = urllib.parse.splituser(realhost)
# 2020-05-06 05:02:10,981 : INFO : Received 1000 entries
# 2020-05-06 05:02:11,009 : INFO : Fetch from arxiv (inf results left to download)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2848: DeprecationWarning: urllib.parse.splittype() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   urltype, rest = urllib.parse.splittype(url_file_stream_or_string)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2849: DeprecationWarning: urllib.parse.splithost() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   realhost, rest = urllib.parse.splithost(rest)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2851: DeprecationWarning: urllib.parse.splituser() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   user_passwd, realhost = urllib.parse.splituser(realhost)
# 2020-05-06 05:02:16,773 : INFO : Received 222 entries
# 2020-05-06 05:02:16,784 : INFO : Fetch from arxiv (inf results left to download)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2848: DeprecationWarning: urllib.parse.splittype() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   urltype, rest = urllib.parse.splittype(url_file_stream_or_string)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2849: DeprecationWarning: urllib.parse.splithost() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   realhost, rest = urllib.parse.splithost(rest)
# /Users/diyosko7/Workspace/arxiv-analysis/venv/lib/python3.8/site-packages/feedparser.py:2851: DeprecationWarning: urllib.parse.splituser() is deprecated as of 3.8, use urllib.parse.urlparse() instead
#   user_passwd, realhost = urllib.parse.splituser(realhost)
# 2020-05-06 05:02:17,351 : INFO : Received 0 entries
# 2020-05-06 05:02:17,352 : INFO : No more entries left to fetch.
# 2020-05-06 05:02:17,353 : INFO : Fetching finished.

# %%
columns = ["id","updated","published","title","summary","authors","tags"]
papers_df = pd.DataFrame(papers,columns=columns)
print(papers_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4222 entries, 0 to 4221
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         4222 non-null   object
#  1   updated    4222 non-null   object
#  2   published  4222 non-null   object
#  3   title      4222 non-null   object
#  4   summary    4222 non-null   object
#  5   authors    4222 non-null   object
#  6   tags       4222 non-null   object
# dtypes: object(7)
# memory usage: 231.0+ KB
# None

# %%
papers_df.head()
# Out:
#                                   id               updated  \
# 0  http://arxiv.org/abs/2005.01205v1  2020-05-03T23:24:10Z
# 1  http://arxiv.org/abs/2005.01174v1  2020-05-03T20:04:51Z
# 2  http://arxiv.org/abs/2005.00609v1  2020-05-01T21:05:24Z
# 3  http://arxiv.org/abs/2005.00277v1  2020-05-01T09:14:43Z
# 4  http://arxiv.org/abs/2005.00241v1  2020-05-01T06:27:55Z
#
#               published                                              title  \
# 0  2020-05-03T23:24:10Z  Electronic Structure of Amorphous Copper Iodid...
# 1  2020-05-03T20:04:51Z  MoS$_2$-on-paper optoelectronics: drawing phot...
# 2  2020-05-01T21:05:24Z  Thiophene-Tetrathia-Annulene monolayer (TTA-2D...
# 3  2020-05-01T09:14:43Z  Accuracy of hybrid functionals with non-self-c...
# 4  2020-05-01T06:27:55Z  Directly visualizing the momentum forbidden da...
#
#                                              summary  \
# 0  The atomic and electronic structure of the p-t...
# 1  We fabricate paper-supported semiconducting de...
# 2  We propose a new 2D semiconductor material (TT...
# 3  Accurately modeling the electronic structure o...
# 4  Resolving the momentum degree of freedom of ex...
#
#                                              authors  \
# 0        [Zhaofu Zhang, Yuzheng Guo, John Robertson]
# 1  [Ali Mazaheri, Riccardo Frisenda, Andres Caste...
# 2  [Raphael M. Tromer, Leonardo D. Machado, Crist...
# 3  [Jonathan M. Skelton, David S. D. Gunn, Sebast...
# 4  [Julien Madéo, Michael K. L. Man, Chakradhar S...
#
#                                                 tags
# 0  [{'term': 'cond-mat.mtrl-sci', 'scheme': 'http...
# 1  [{'term': 'physics.app-ph', 'scheme': 'http://...
# 2  [{'term': 'cond-mat.mtrl-sci', 'scheme': 'http...
# 3  [{'term': 'cond-mat.mtrl-sci', 'scheme': 'http...
# 4  [{'term': 'cond-mat.mtrl-sci', 'scheme': 'http...

# %% [markdown]
# ## Summary から名詞抽出

# %%
from tqdm import tqdm
def get_nounlist(text):
    tokenized = nltk.word_tokenize(text)
    noun_list = [word for (word, pos) in nltk.pos_tag(tokenized) if(pos[:2] == 'NN')]
    return noun_list
nouns_summarys = []
for text in tqdm(papers_df.summary.tolist()):
    nouns_summarys.append(" ".join(get_nounlist(text)))
print("noun num: "+ str(len(" ".join(nouns_summarys).split())))
# Out:
# 100%|██████████| 4222/4222 [00:29<00:00, 144.95it/s]
# noun num: 4222

# %% [markdown]
# ## WordCloud 描写

# %%
def plot_wordcloud(wordcloud):
    plt.figure(figsize=(6,8),dpi=200)
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    
wordcloud = WordCloud(stopwords=STOPWORDS, max_words=300,height=420,width=640)
wordcloud.generate(" ".join(nouns_summarys))
wordcloud.to_file('../images/wordcloud_nouns.png')
plot_wordcloud(wordcloud)

# %%
from gensim.models.word2vec import Word2Vec
import gensim.downloader as api

corpus = api.load('text8') #  前処理済みWikipedia コーパス
model = Word2Vec(corpus)
model.most_similar(positive=['semiconductor'], topn = 30)
# Out:
# [==================================================] 100.0% 31.6/31.6MB downloaded
# <ipython-input-134-f0d487ef9319>:6: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   model.most_similar(positive=['semiconductor'], topn = 30)
# [('silicon', 0.83039391040802),
#  ('nanotube', 0.8207775354385376),
#  ('diodes', 0.8022797703742981),
#  ('lasers', 0.7996277213096619),
#  ('transistor', 0.7961293458938599),
#  ('diode', 0.789599597454071),
#  ('sensor', 0.7800287008285522),
#  ('flywheel', 0.7786636352539062),
#  ('hydraulic', 0.7777989506721497),
#  ('electronics', 0.777155876159668),
#  ('fabrication', 0.7723093628883362),
#  ('generators', 0.7677658796310425),
#  ('fibre', 0.7664064168930054),
#  ('battery', 0.7657605409622192),
#  ('capacitor', 0.7627253532409668),
#  ('germanium', 0.759238600730896),
#  ('nanotubes', 0.7571440935134888),
#  ('composite', 0.7559075355529785),
#  ('electrical', 0.7543782591819763),
#  ('sensors', 0.7528113722801208),
#  ('pickup', 0.7527279257774353),
#  ('laser', 0.7519397735595703),
#  ('amplifier', 0.7505814433097839),
#  ('semiconductors', 0.7492596507072449),
#  ('aluminium', 0.7488459348678589),
#  ('transformer', 0.7477387189865112),
#  ('fiber', 0.7455847263336182),
#  ('amplifiers', 0.745204746723175),
#  ('catalytic', 0.7450881004333496),
#  ('ccd', 0.7443492412567139)]

# %%
from time import time
from tqdm import tqdm
def get_nounlist(text):
    tokenized = nltk.word_tokenize(text)
    noun_list = [word for (word, pos) in nltk.pos_tag(tokenized) if(pos[:2] == 'NN')]
    return noun_list
nouns_summarys = []
for text in tqdm(papers_df.summary.tolist()):
    nouns_summarys.append(get_nounlist(text))

w2v_model_semicon = Word2Vec(size=100, window=5, min_count=1, workers=4)
print(len(nouns_summarys))
start_time = time()
w2v_model_semicon.build_vocab(nouns_summarys, progress_per=10000) #
print('Time to build vocab: {} mins'.format(round((time() - start_time) / 60, 2)))

start_time = time()
w2v_model_semicon.train(nouns_summarys, total_examples=w2v_model_semicon.corpus_count, epochs=30, report_delay=1)
print('Time to train the model: {} mins'.format(round((time() - start_time) / 60, 2)))
# Out:
# 100%|██████████| 4222/4222 [00:27<00:00, 152.33it/s]
# 4222
# Time to build vocab: 0.05 mins
# Time to train the model: 0.07 mins

# %%
w2v_model_semicon.most_similar(positive=['semiconductor'], topn = 50)
# Out:
# <ipython-input-157-f3a7342a0277>:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   w2v_model_semicon.most_similar(positive=['semiconductor'], topn = 50)
# [('Semiconductor', 0.4802175760269165),
#  ('multi-quantum', 0.47473210096359253),
#  ('Due', 0.45609554648399353),
#  ('turnstile', 0.435139536857605),
#  ('-SbN', 0.4167560636997223),
#  ('nanocavities', 0.4149588346481323),
#  ('dot-in-a-nanowire', 0.41413354873657227),
#  ('core/shell', 0.41368210315704346),
#  ('thinness', 0.41305011510849),
#  ('silicon-on-insulator', 0.41270533204078674),
#  ('arms', 0.4067515730857849),
#  ('QMBE', 0.40551435947418213),
#  ('Nanoscale', 0.4026905596256256),
#  ('S-Sm-S', 0.40253937244415283),
#  ('Hendricks-', 0.40239280462265015),
#  ('manufacturability', 0.40135428309440613),
#  ('Johnson', 0.39907047152519226),
#  ('Fronts', 0.3974401652812958),
#  ('InAs/GaSb', 0.3863407373428345),
#  ('Anomalies', 0.3850015103816986),
#  ('Bottom', 0.3848538398742676),
#  ('controls', 0.3847142159938812),
#  ('In0.53Ga0.47As', 0.38403791189193726),
#  ('evidences', 0.38242918252944946),
#  ('Teller', 0.3818452060222626),
#  ('GaInNAs', 0.37963688373565674),
#  ('GaAs/GaSb', 0.3793639540672302),
#  ('GaAs-AlGaAs', 0.3787282705307007),
#  ('InAs/EuS/Al', 0.3771384656429291),
#  ('disclination', 0.377107709646225),
#  ('possibility', 0.3760830760002136),
#  ('near-fields', 0.3758922517299652),
#  ('prospect', 0.37364649772644043),
#  ('superconductor-semiconductor-superconductor', 0.3725839853286743),
#  ('quantum', 0.3725670874118805),
#  ('gas', 0.3724437355995178),
#  ('consisting', 0.37211859226226807),
#  ('semiconducting', 0.3719736933708191),
#  ('heterostructures', 0.3709437847137451),
#  ('SQDs', 0.3698841631412506),
#  ('AlGaAs/GaAs/AlGaAs', 0.36969321966171265),
#  ('contacting', 0.3694254457950592),
#  ('interplay', 0.3688565194606781),
#  ('CPT', 0.36716800928115845),
#  ('superconductor-metal-superconductor', 0.3668338656425476),
#  ('ability', 0.36558884382247925),
#  ('core/semiconductor', 0.36511969566345215),
#  ('AlGaAs/GaAs', 0.3643571734428406),
#  ('telecomm', 0.36403343081474304),
#  ('pertinent', 0.36252328753471375)]

# %%
w2v_model_semicon.most_similar(positive=['GaAsBi'], topn = 50)
# Out:
# <ipython-input-158-afe17d67ec5e>:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   w2v_model_semicon.most_similar(positive=['GaAsBi'], topn = 50)
# [('epitaxy', 0.7212064266204834),
#  ('ErAs', 0.714539647102356),
#  ('alloying', 0.7112866044044495),
#  ('Ge/1-x/Cr/x/Te', 0.7077975273132324),
#  ('Ge-Sb-Te', 0.7048461437225342),
#  ('homoepitaxy', 0.6981136798858643),
#  ('fulfill', 0.6920899152755737),
#  ('Ge1-xMn', 0.6906101107597351),
#  ('MBE', 0.68761146068573),
#  ('crystallines', 0.6860561370849609),
#  ('epilayers', 0.6815122365951538),
#  ('phase-transitions', 0.6781480312347412),
#  ('Zn/1-x-y/Cd/x/Mn/y/GeAs/2/', 0.6776307821273804),
#  ('Vibration', 0.6748820543289185),
#  ('Ge-As-Te', 0.6669707298278809),
#  ('monocrystalline', 0.666419267654419),
#  ('Instruments', 0.6656162738800049),
#  ('Fe3Si', 0.6636375188827515),
#  ('Co2FeSi', 0.6604992747306824),
#  ('arc-melting', 0.658313512802124),
#  ('IV-VI', 0.6544854640960693),
#  ('xTe', 0.6540685296058655),
#  ('Zn', 0.6535360813140869),
#  ('polycrystalline', 0.6534479260444641),
#  ('tend', 0.6532332301139832),
#  ('Fe2+', 0.6505139470100403),
#  ('I-II-V', 0.6474097371101379),
#  ('Zn1-xMnx', 0.6468015909194946),
#  ('In-In', 0.6458849906921387),
#  ('GeMn', 0.6457570791244507),
#  ('III-Mn-V', 0.6455762386322021),
#  ('x=0.14', 0.6427377462387085),
#  ('nanoislands', 0.6406219005584717),
#  ('Kelvinox', 0.6401244401931763),
#  ('antimonides', 0.6397039890289307),
#  ('AlSb/InAs/', 0.6369555592536926),
#  ('Reconstruction', 0.6369411945343018),
#  ('BeMnTe', 0.6359211206436157),
#  ('refinement', 0.6359044313430786),
#  ('milling', 0.635791540145874),
#  ('cadmium', 0.6350076198577881),
#  ('segregation', 0.6338884830474854),
#  ('doubly', 0.6333827376365662),
#  ('SkL', 0.6316202878952026),
#  ('Oxford', 0.6312700510025024),
#  ('Few-layer', 0.6309291124343872),
#  ('SCS', 0.6308645009994507),
#  ('ion', 0.6300562620162964),
#  ('adsorbate', 0.6289746761322021),
#  ('MBE-growth', 0.6281154751777649)]

# %%
corpus = [dictionary.doc2bow(t) for t in nouns_summarys]

dictionary = gensim.corpora.Dictionary(nouns_summarys)
print('vocab size: ', len(dictionary))

tfidf = gensim.models.TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]
# Out:
# 2020-05-06 04:31:40,492 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-05-06 04:31:40,707 : INFO : built Dictionary(13559 unique tokens: ['-Cu', '-I', 'CuI', 'Fermi', 'H.']...) from 4222 documents (total 189011 corpus positions)
# 2020-05-06 04:31:40,708 : INFO : collecting document frequencies
# 2020-05-06 04:31:40,709 : INFO : PROGRESS: processing document #0
# 2020-05-06 04:31:40,742 : INFO : calculating IDF weights for 4222 documents and 13559 features (143520 matrix non-zeros)
# vocab size:  13559

# %%
#Metrics for Topic Models
start = 2
limit = 22
step = 1

coherence_vals = []
perplexity_vals = []

for n_topic in tqdm(range(start, limit, step)):
    lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus, id2word=dictionary, num_topics=n_topic, random_state=0)
    perplexity_vals.append(np.exp2(-lda_model.log_perplexity(corpus)))
    coherence_model_lda = gensim.models.CoherenceModel(model=lda_model, texts=nouns_summarys, dictionary=dictionary, coherence='c_v')
    coherence_vals.append(coherence_model_lda.get_coherence())
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]2020-05-06 04:31:47,112 : INFO : using symmetric alpha at 0.5
# 2020-05-06 04:31:47,113 : INFO : using symmetric eta at 0.5
# 2020-05-06 04:31:47,118 : INFO : using serial LDA version on this node
# 2020-05-06 04:31:47,123 : INFO : running online (single-pass) LDA training, 2 topics, 1 passes over the supplied corpus of 4222 documents, updating model once every 2000 documents, evaluating perplexity every 4222 documents, iterating 50x with a convergence threshold of 0.001000
# 2020-05-06 04:31:47,124 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2020-05-06 04:31:47,126 : INFO : PROGRESS: pass 0, at document #2000/4222
# 2020-05-06 04:31:48,818 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:31:48,823 : INFO : topic #0 (0.500): 0.012*"semiconductor" + 0.008*"field" + 0.008*"band" + 0.007*"model" + 0.006*"results" + 0.006*"properties" + 0.006*"materials" + 0.005*"temperature" + 0.005*"states" + 0.005*"semiconductors"
# 2020-05-06 04:31:48,825 : INFO : topic #1 (0.500): 0.013*"semiconductor" + 0.011*"semiconductors" + 0.010*"quantum" + 0.009*"spin" + 0.008*"energy" + 0.007*"properties" + 0.007*"band" + 0.007*"states" + 0.006*"materials" + 0.006*"structure"
# 2020-05-06 04:31:48,826 : INFO : topic diff=2.069805, rho=1.000000
# 2020-05-06 04:31:48,827 : INFO : PROGRESS: pass 0, at document #4000/4222
# 2020-05-06 04:31:50,332 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:31:50,335 : INFO : topic #0 (0.500): 0.015*"semiconductor" + 0.011*"field" + 0.008*"model" + 0.007*"temperature" + 0.006*"band" + 0.006*"results" + 0.006*"transport" + 0.005*"electron" + 0.005*"semiconductors" + 0.005*"effect"
# 2020-05-06 04:31:50,336 : INFO : topic #1 (0.500): 0.016*"spin" + 0.015*"semiconductor" + 0.014*"quantum" + 0.011*"semiconductors" + 0.008*"energy" + 0.007*"field" + 0.007*"states" + 0.007*"electron" + 0.007*"Mn" + 0.007*"temperature"
# 2020-05-06 04:31:50,337 : INFO : topic diff=0.948533, rho=0.707107
# 2020-05-06 04:31:50,565 : INFO : -7.724 per-word bound, 211.4 perplexity estimate based on a held-out corpus of 222 documents with 8091 words
# 2020-05-06 04:31:50,566 : INFO : PROGRESS: pass 0, at document #4222/4222
# 2020-05-06 04:31:50,736 : INFO : merging changes from 222 documents into a model of 4222 documents
# 2020-05-06 04:31:50,739 : INFO : topic #0 (0.500): 0.015*"semiconductor" + 0.013*"field" + 0.010*"model" + 0.008*"temperature" + 0.007*"states" + 0.006*"band" + 0.006*"surface" + 0.006*"results" + 0.006*"effect" + 0.006*"electron"
# 2020-05-06 04:31:50,740 : INFO : topic #1 (0.500): 0.018*"quantum" + 0.014*"semiconductor" + 0.013*"spin" + 0.011*"semiconductors" + 0.009*"energy" + 0.009*"states" + 0.008*"electron" + 0.008*"field" + 0.008*"density" + 0.007*"interaction"
# 2020-05-06 04:31:50,741 : INFO : topic diff=0.622828, rho=0.577350
# 2020-05-06 04:31:54,207 : INFO : -7.772 per-word bound, 218.6 perplexity estimate based on a held-out corpus of 4222 documents with 189011 words
# 2020-05-06 04:31:54,209 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2020-05-06 04:31:56,627 : INFO : 3 accumulators retrieved from output queue
# 2020-05-06 04:31:56,650 : INFO : accumulated word occurrence stats for 4224 virtual documents
#   5%|▌         | 1/20 [00:09<03:03,  9.64s/it]2020-05-06 04:31:56,751 : INFO : using symmetric alpha at 0.3333333333333333
# 2020-05-06 04:31:56,752 : INFO : using symmetric eta at 0.3333333333333333
# 2020-05-06 04:31:56,756 : INFO : using serial LDA version on this node
# 2020-05-06 04:31:56,761 : INFO : running online (single-pass) LDA training, 3 topics, 1 passes over the supplied corpus of 4222 documents, updating model once every 2000 documents, evaluating perplexity every 4222 documents, iterating 50x with a convergence threshold of 0.001000
# 2020-05-06 04:31:56,762 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2020-05-06 04:31:56,765 : INFO : PROGRESS: pass 0, at document #2000/4222
# 2020-05-06 04:31:58,241 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:31:58,245 : INFO : topic #0 (0.333): 0.011*"semiconductor" + 0.008*"band" + 0.008*"model" + 0.008*"field" + 0.006*"results" + 0.006*"states" + 0.006*"temperature" + 0.006*"materials" + 0.005*"semiconductors" + 0.005*"devices"
# 2020-05-06 04:31:58,246 : INFO : topic #1 (0.333): 0.012*"semiconductor" + 0.011*"semiconductors" + 0.009*"quantum" + 0.009*"energy" + 0.008*"band" + 0.007*"spin" + 0.007*"states" + 0.006*"charge" + 0.006*"materials" + 0.006*"properties"
# 2020-05-06 04:31:58,246 : INFO : topic #2 (0.333): 0.015*"semiconductor" + 0.010*"properties" + 0.010*"quantum" + 0.009*"spin" + 0.008*"transport" + 0.008*"field" + 0.008*"semiconductors" + 0.007*"electron" + 0.007*"results" + 0.006*"effect"
# 2020-05-06 04:31:58,248 : INFO : topic diff=2.517659, rho=1.000000
# 2020-05-06 04:31:58,250 : INFO : PROGRESS: pass 0, at document #4000/4222
# 2020-05-06 04:31:59,799 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:31:59,802 : INFO : topic #0 (0.333): 0.013*"semiconductor" + 0.010*"field" + 0.010*"model" + 0.007*"band" + 0.007*"temperature" + 0.006*"results" + 0.006*"electrons" + 0.006*"states" + 0.006*"semiconductors" + 0.005*"energy"
# 2020-05-06 04:31:59,804 : INFO : topic #1 (0.333): 0.013*"semiconductor" + 0.013*"quantum" + 0.012*"semiconductors" + 0.010*"spin" + 0.009*"energy" + 0.008*"states" + 0.008*"Mn" + 0.008*"interaction" + 0.007*"band" + 0.007*"temperature"
# 2020-05-06 04:31:59,805 : INFO : topic #2 (0.333): 0.019*"spin" + 0.018*"semiconductor" + 0.012*"quantum" + 0.011*"electron" + 0.011*"field" + 0.010*"transport" + 0.009*"effect" + 0.007*"properties" + 0.007*"semiconductors" + 0.007*"results"
# 2020-05-06 04:31:59,806 : INFO : topic diff=1.028280, rho=0.707107
# 2020-05-06 04:32:00,048 : INFO : -7.836 per-word bound, 228.5 perplexity estimate based on a held-out corpus of 222 documents with 8091 words
# 2020-05-06 04:32:00,049 : INFO : PROGRESS: pass 0, at document #4222/4222
# 2020-05-06 04:32:00,235 : INFO : merging changes from 222 documents into a model of 4222 documents
# 2020-05-06 04:32:00,239 : INFO : topic #0 (0.333): 0.014*"field" + 0.013*"semiconductor" + 0.013*"model" + 0.008*"temperature" + 0.008*"states" + 0.008*"surface" + 0.008*"band" + 0.006*"semiconductors" + 0.006*"electrons" + 0.005*"energy"
# 2020-05-06 04:32:00,240 : INFO : topic #1 (0.333): 0.018*"quantum" + 0.013*"semiconductor" + 0.011*"semiconductors" + 0.010*"states" + 0.009*"energy" + 0.009*"interaction" + 0.009*"density" + 0.008*"band" + 0.008*"spin" + 0.008*"model"
# 2020-05-06 04:32:00,241 : INFO : topic #2 (0.333): 0.020*"semiconductor" + 0.015*"spin" + 0.015*"electron" + 0.012*"field" + 0.012*"quantum" + 0.010*"effect" + 0.009*"transport" + 0.008*"temperature" + 0.007*"results" + 0.007*"semiconductors"
# 2020-05-06 04:32:00,242 : INFO : topic diff=0.667974, rho=0.577350
# 2020-05-06 04:32:03,512 : INFO : -7.815 per-word bound, 225.1 perplexity estimate based on a held-out corpus of 4222 documents with 189011 words
# 2020-05-06 04:32:03,515 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2020-05-06 04:32:06,009 : INFO : 3 accumulators retrieved from output queue
# 2020-05-06 04:32:06,029 : INFO : accumulated word occurrence stats for 4250 virtual documents
#  10%|█         | 2/20 [00:19<02:52,  9.58s/it]2020-05-06 04:32:06,183 : INFO : using symmetric alpha at 0.25
# 2020-05-06 04:32:06,184 : INFO : using symmetric eta at 0.25
# 2020-05-06 04:32:06,191 : INFO : using serial LDA version on this node
# 2020-05-06 04:32:06,199 : INFO : running online (single-pass) LDA training, 4 topics, 1 passes over the supplied corpus of 4222 documents, updating model once every 2000 documents, evaluating perplexity every 4222 documents, iterating 50x with a convergence threshold of 0.001000
# 2020-05-06 04:32:06,201 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2020-05-06 04:32:06,203 : INFO : PROGRESS: pass 0, at document #2000/4222
# 2020-05-06 04:32:07,677 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:32:07,681 : INFO : topic #0 (0.250): 0.011*"semiconductor" + 0.008*"band" + 0.006*"states" + 0.006*"field" + 0.006*"results" + 0.006*"devices" + 0.006*"temperature" + 0.005*"materials" + 0.005*"electrons" + 0.005*"semiconductors"
# 2020-05-06 04:32:07,683 : INFO : topic #1 (0.250): 0.012*"semiconductor" + 0.011*"semiconductors" + 0.011*"quantum" + 0.011*"energy" + 0.008*"spin" + 0.008*"states" + 0.007*"band" + 0.006*"interaction" + 0.006*"properties" + 0.006*"charge"
# 2020-05-06 04:32:07,684 : INFO : topic #2 (0.250): 0.016*"semiconductor" + 0.011*"spin" + 0.011*"quantum" + 0.010*"properties" + 0.009*"transport" + 0.008*"electron" + 0.007*"semiconductors" + 0.007*"effect" + 0.007*"results" + 0.007*"field"
# 2020-05-06 04:32:07,685 : INFO : topic #3 (0.250): 0.011*"semiconductor" + 0.011*"model" + 0.010*"field" + 0.009*"band" + 0.009*"semiconductors" + 0.007*"properties" + 0.007*"materials" + 0.006*"structure" + 0.006*"phase" + 0.006*"temperature"
# 2020-05-06 04:32:07,687 : INFO : topic diff=3.072778, rho=1.000000
# 2020-05-06 04:32:07,691 : INFO : PROGRESS: pass 0, at document #4000/4222
# 2020-05-06 04:32:09,052 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:32:09,055 : INFO : topic #0 (0.250): 0.014*"semiconductor" + 0.007*"field" + 0.007*"electrons" + 0.006*"states" + 0.006*"temperature" + 0.006*"band" + 0.006*"results" + 0.005*"energy" + 0.005*"model" + 0.005*"semiconductors"
# 2020-05-06 04:32:09,057 : INFO : topic #1 (0.250): 0.017*"quantum" + 0.015*"semiconductor" + 0.013*"spin" + 0.010*"semiconductors" + 0.010*"states" + 0.010*"energy" + 0.009*"interaction" + 0.006*"Mn" + 0.006*"coupling" + 0.006*"density"
# 2020-05-06 04:32:09,058 : INFO : topic #2 (0.250): 0.023*"spin" + 0.020*"semiconductor" + 0.014*"quantum" + 0.013*"electron" + 0.011*"transport" + 0.010*"effect" + 0.010*"field" + 0.007*"results" + 0.007*"properties" + 0.006*"semiconductors"
# 2020-05-06 04:32:09,060 : INFO : topic #3 (0.250): 0.014*"model" + 0.012*"field" + 0.012*"semiconductor" + 0.011*"semiconductors" + 0.010*"band" + 0.009*"temperature" + 0.008*"Mn" + 0.007*"theory" + 0.007*"structure" + 0.006*"results"
# 2020-05-06 04:32:09,061 : INFO : topic diff=1.065475, rho=0.707107
# 2020-05-06 04:32:09,289 : INFO : -7.938 per-word bound, 245.3 perplexity estimate based on a held-out corpus of 222 documents with 8091 words
# 2020-05-06 04:32:09,289 : INFO : PROGRESS: pass 0, at document #4222/4222
# 2020-05-06 04:32:09,444 : INFO : merging changes from 222 documents into a model of 4222 documents
# 2020-05-06 04:32:09,451 : INFO : topic #0 (0.250): 0.014*"semiconductor" + 0.010*"states" + 0.009*"field" + 0.009*"electrons" + 0.007*"emission" + 0.007*"interface" + 0.007*"temperature" + 0.006*"band" + 0.006*"conductance" + 0.006*"model"
# 2020-05-06 04:32:09,453 : INFO : topic #1 (0.250): 0.025*"quantum" + 0.014*"semiconductor" + 0.011*"states" + 0.011*"interaction" + 0.010*"energy" + 0.010*"semiconductors" + 0.009*"spin" + 0.009*"density" + 0.006*"dots" + 0.006*"effects"
# 2020-05-06 04:32:09,461 : INFO : topic #2 (0.250): 0.022*"semiconductor" + 0.020*"spin" + 0.017*"electron" + 0.013*"quantum" + 0.011*"effect" + 0.010*"field" + 0.010*"transport" + 0.007*"results" + 0.006*"system" + 0.006*"temperature"
# 2020-05-06 04:32:09,463 : INFO : topic #3 (0.250): 0.016*"model" + 0.014*"field" + 0.012*"semiconductor" + 0.011*"semiconductors" + 0.011*"temperature" + 0.010*"band" + 0.009*"surface" + 0.008*"structure" + 0.007*"theory" + 0.007*"results"
# 2020-05-06 04:32:09,468 : INFO : topic diff=0.698308, rho=0.577350
# 2020-05-06 04:32:12,730 : INFO : -7.847 per-word bound, 230.2 perplexity estimate based on a held-out corpus of 4222 documents with 189011 words
# 2020-05-06 04:32:12,733 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2020-05-06 04:32:15,267 : INFO : 3 accumulators retrieved from output queue
# 2020-05-06 04:32:15,277 : INFO : accumulated word occurrence stats for 4256 virtual documents
#  15%|█▌        | 3/20 [00:28<02:41,  9.48s/it]2020-05-06 04:32:15,432 : INFO : using symmetric alpha at 0.2
# 2020-05-06 04:32:15,433 : INFO : using symmetric eta at 0.2
# 2020-05-06 04:32:15,436 : INFO : using serial LDA version on this node
# 2020-05-06 04:32:15,444 : INFO : running online (single-pass) LDA training, 5 topics, 1 passes over the supplied corpus of 4222 documents, updating model once every 2000 documents, evaluating perplexity every 4222 documents, iterating 50x with a convergence threshold of 0.001000
# 2020-05-06 04:32:15,445 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2020-05-06 04:32:15,447 : INFO : PROGRESS: pass 0, at document #2000/4222
# 2020-05-06 04:32:16,851 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:32:16,855 : INFO : topic #0 (0.200): 0.010*"semiconductor" + 0.007*"band" + 0.006*"states" + 0.006*"results" + 0.006*"devices" + 0.006*"field" + 0.006*"materials" + 0.006*"temperature" + 0.005*"semiconductors" + 0.005*"energy"
# 2020-05-06 04:32:16,857 : INFO : topic #1 (0.200): 0.012*"semiconductors" + 0.011*"semiconductor" + 0.011*"energy" + 0.010*"quantum" + 0.008*"spin" + 0.008*"states" + 0.007*"band" + 0.006*"materials" + 0.006*"results" + 0.006*"properties"
# 2020-05-06 04:32:16,858 : INFO : topic #2 (0.200): 0.015*"semiconductor" + 0.011*"spin" + 0.010*"properties" + 0.010*"transport" + 0.009*"quantum" + 0.008*"electron" + 0.008*"semiconductors" + 0.008*"results" + 0.007*"field" + 0.007*"devices"
# 2020-05-06 04:32:16,860 : INFO : topic #3 (0.200): 0.011*"model" + 0.010*"semiconductor" + 0.010*"band" + 0.009*"field" + 0.009*"semiconductors" + 0.008*"materials" + 0.007*"structure" + 0.007*"properties" + 0.006*"temperature" + 0.006*"phase"
# 2020-05-06 04:32:16,862 : INFO : topic #4 (0.200): 0.015*"semiconductor" + 0.011*"quantum" + 0.008*"spin" + 0.008*"band" + 0.007*"field" + 0.007*"semiconductors" + 0.007*"properties" + 0.006*"states" + 0.006*"charge" + 0.006*"state"
# 2020-05-06 04:32:16,864 : INFO : topic diff=3.704983, rho=1.000000
# 2020-05-06 04:32:16,868 : INFO : PROGRESS: pass 0, at document #4000/4222
# 2020-05-06 04:32:18,152 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:32:18,156 : INFO : topic #0 (0.200): 0.013*"semiconductor" + 0.007*"field" + 0.006*"states" + 0.006*"electrons" + 0.006*"results" + 0.006*"temperature" + 0.006*"band" + 0.006*"emission" + 0.005*"energy" + 0.005*"devices"
# 2020-05-06 04:32:18,158 : INFO : topic #1 (0.200): 0.015*"quantum" + 0.013*"semiconductor" + 0.011*"semiconductors" + 0.010*"energy" + 0.010*"spin" + 0.010*"states" + 0.008*"interaction" + 0.006*"exchange" + 0.006*"dots" + 0.006*"results"
# 2020-05-06 04:32:18,161 : INFO : topic #2 (0.200): 0.021*"spin" + 0.018*"semiconductor" + 0.014*"electron" + 0.014*"transport" + 0.010*"quantum" + 0.009*"field" + 0.009*"effect" + 0.008*"properties" + 0.007*"results" + 0.007*"semiconductors"
# 2020-05-06 04:32:18,163 : INFO : topic #3 (0.200): 0.014*"model" + 0.012*"semiconductors" + 0.011*"field" + 0.011*"band" + 0.011*"semiconductor" + 0.010*"temperature" + 0.009*"Mn" + 0.008*"structure" + 0.007*"results" + 0.007*"theory"
# 2020-05-06 04:32:18,166 : INFO : topic #4 (0.200): 0.018*"semiconductor" + 0.016*"spin" + 0.015*"quantum" + 0.010*"field" + 0.008*"effect" + 0.008*"state" + 0.007*"electron" + 0.007*"semiconductors" + 0.007*"states" + 0.007*"system"
# 2020-05-06 04:32:18,167 : INFO : topic diff=1.059809, rho=0.707107
# 2020-05-06 04:32:18,365 : INFO : -8.039 per-word bound, 262.9 perplexity estimate based on a held-out corpus of 222 documents with 8091 words
# 2020-05-06 04:32:18,365 : INFO : PROGRESS: pass 0, at document #4222/4222
# 2020-05-06 04:32:18,510 : INFO : merging changes from 222 documents into a model of 4222 documents
# 2020-05-06 04:32:18,514 : INFO : topic #0 (0.200): 0.013*"semiconductor" + 0.011*"field" + 0.009*"emission" + 0.009*"states" + 0.007*"barrier" + 0.007*"electrons" + 0.007*"temperature" + 0.006*"conductance" + 0.006*"SL" + 0.006*"reflection"
# 2020-05-06 04:32:18,515 : INFO : topic #1 (0.200): 0.021*"quantum" + 0.012*"semiconductors" + 0.011*"semiconductor" + 0.011*"states" + 0.010*"energy" + 0.007*"spin" + 0.007*"interaction" + 0.007*"dots" + 0.007*"results" + 0.006*"exciton"
# 2020-05-06 04:32:18,515 : INFO : topic #2 (0.200): 0.020*"semiconductor" + 0.014*"spin" + 0.014*"transport" + 0.013*"electron" + 0.011*"quantum" + 0.010*"effect" + 0.008*"field" + 0.007*"properties" + 0.007*"results" + 0.007*"devices"
# 2020-05-06 04:32:18,517 : INFO : topic #3 (0.200): 0.018*"model" + 0.014*"temperature" + 0.013*"surface" + 0.012*"band" + 0.012*"semiconductors" + 0.011*"field" + 0.010*"structure" + 0.010*"semiconductor" + 0.009*"results" + 0.008*"theory"
# 2020-05-06 04:32:18,519 : INFO : topic #4 (0.200): 0.019*"semiconductor" + 0.016*"quantum" + 0.013*"field" + 0.012*"spin" + 0.010*"electron" + 0.009*"density" + 0.009*"states" + 0.009*"energy" + 0.008*"model" + 0.008*"interaction"
# 2020-05-06 04:32:18,522 : INFO : topic diff=0.711763, rho=0.577350
# 2020-05-06 04:32:21,417 : INFO : -7.874 per-word bound, 234.6 perplexity estimate based on a held-out corpus of 4222 documents with 189011 words
# 2020-05-06 04:32:21,420 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2020-05-06 04:32:23,689 : INFO : 3 accumulators retrieved from output queue
# 2020-05-06 04:32:23,714 : INFO : accumulated word occurrence stats for 4259 virtual documents
#  20%|██        | 4/20 [00:36<02:26,  9.17s/it]2020-05-06 04:32:23,882 : INFO : using symmetric alpha at 0.16666666666666666
# 2020-05-06 04:32:23,883 : INFO : using symmetric eta at 0.16666666666666666
# 2020-05-06 04:32:23,887 : INFO : using serial LDA version on this node
# 2020-05-06 04:32:23,896 : INFO : running online (single-pass) LDA training, 6 topics, 1 passes over the supplied corpus of 4222 documents, updating model once every 2000 documents, evaluating perplexity every 4222 documents, iterating 50x with a convergence threshold of 0.001000
# 2020-05-06 04:32:23,897 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2020-05-06 04:32:23,900 : INFO : PROGRESS: pass 0, at document #2000/4222
# 2020-05-06 04:32:25,290 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:32:25,294 : INFO : topic #5 (0.167): 0.016*"semiconductor" + 0.012*"energy" + 0.011*"semiconductors" + 0.008*"transition" + 0.007*"materials" + 0.007*"devices" + 0.007*"temperature" + 0.006*"model" + 0.006*"states" + 0.006*"band"
# 2020-05-06 04:32:25,295 : INFO : topic #0 (0.167): 0.010*"semiconductor" + 0.008*"band" + 0.007*"results" + 0.006*"states" + 0.006*"field" + 0.006*"devices" + 0.006*"materials" + 0.006*"temperature" + 0.005*"applications" + 0.005*"electrons"
# 2020-05-06 04:32:25,297 : INFO : topic #4 (0.167): 0.014*"semiconductor" + 0.012*"quantum" + 0.009*"spin" + 0.008*"band" + 0.008*"field" + 0.007*"charge" + 0.007*"properties" + 0.007*"effect" + 0.006*"states" + 0.006*"semiconductors"
# 2020-05-06 04:32:25,298 : INFO : topic #3 (0.167): 0.011*"model" + 0.011*"field" + 0.010*"band" + 0.010*"semiconductor" + 0.009*"semiconductors" + 0.008*"structure" + 0.008*"properties" + 0.008*"materials" + 0.006*"results" + 0.006*"phase"
# 2020-05-06 04:32:25,300 : INFO : topic #2 (0.167): 0.015*"semiconductor" + 0.013*"spin" + 0.011*"properties" + 0.011*"transport" + 0.010*"quantum" + 0.009*"electron" + 0.008*"results" + 0.008*"field" + 0.007*"semiconductors" + 0.007*"effect"
# 2020-05-06 04:32:25,301 : INFO : topic diff=4.391267, rho=1.000000
# 2020-05-06 04:32:25,304 : INFO : PROGRESS: pass 0, at document #4000/4222
# 2020-05-06 04:32:26,690 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:32:26,696 : INFO : topic #4 (0.167): 0.018*"semiconductor" + 0.017*"spin" + 0.017*"quantum" + 0.011*"field" + 0.010*"effect" + 0.008*"state" + 0.008*"electron" + 0.007*"interaction" + 0.007*"states" + 0.007*"system"
# 2020-05-06 04:32:26,697 : INFO : topic #0 (0.167): 0.012*"semiconductor" + 0.007*"field" + 0.007*"results" + 0.006*"electrons" + 0.006*"states" + 0.006*"band" + 0.006*"temperature" + 0.006*"polariton" + 0.005*"emission" + 0.005*"energy"
# 2020-05-06 04:32:26,700 : INFO : topic #1 (0.167): 0.016*"quantum" + 0.013*"semiconductor" + 0.010*"spin" + 0.010*"semiconductors" + 0.010*"states" + 0.009*"energy" + 0.007*"interaction" + 0.007*"exchange" + 0.006*"dots" + 0.006*"results"
# 2020-05-06 04:32:26,702 : INFO : topic #5 (0.167): 0.018*"semiconductor" + 0.011*"energy" + 0.011*"semiconductors" + 0.009*"temperature" + 0.008*"transition" + 0.007*"model" + 0.006*"theory" + 0.006*"materials" + 0.006*"states" + 0.005*"exciton"
# 2020-05-06 04:32:26,704 : INFO : topic #2 (0.167): 0.024*"spin" + 0.018*"semiconductor" + 0.015*"electron" + 0.015*"transport" + 0.011*"quantum" + 0.010*"field" + 0.009*"effect" + 0.008*"properties" + 0.008*"results" + 0.007*"semiconductors"
# 2020-05-06 04:32:26,706 : INFO : topic diff=1.017784, rho=0.707107
# 2020-05-06 04:32:26,881 : INFO : -8.149 per-word bound, 283.9 perplexity estimate based on a held-out corpus of 222 documents with 8091 words
# 2020-05-06 04:32:26,881 : INFO : PROGRESS: pass 0, at document #4222/4222
# 2020-05-06 04:32:27,027 : INFO : merging changes from 222 documents into a model of 4222 documents
# 2020-05-06 04:32:27,031 : INFO : topic #3 (0.167): 0.018*"model" + 0.014*"surface" + 0.014*"field" + 0.014*"temperature" + 0.012*"semiconductors" + 0.012*"band" + 0.010*"structure" + 0.009*"results" + 0.009*"semiconductor" + 0.007*"theory"
# 2020-05-06 04:32:27,032 : INFO : topic #0 (0.167): 0.013*"semiconductor" + 0.009*"states" + 0.009*"emission" + 0.009*"field" + 0.008*"reflection" + 0.008*"SL" + 0.007*"conductance" + 0.007*"barrier" + 0.007*"temperature" + 0.006*"gap"
# 2020-05-06 04:32:27,033 : INFO : topic #5 (0.167): 0.018*"semiconductor" + 0.013*"energy" + 0.013*"semiconductors" + 0.010*"model" + 0.009*"temperature" + 0.009*"states" + 0.008*"transition" + 0.006*"theory" + 0.006*"band" + 0.006*"superlattices"
# 2020-05-06 04:32:27,035 : INFO : topic #4 (0.167): 0.020*"quantum" + 0.018*"semiconductor" + 0.014*"field" + 0.013*"spin" + 0.010*"electron" + 0.009*"density" + 0.009*"interaction" + 0.009*"function" + 0.009*"states" + 0.009*"effect"
# 2020-05-06 04:32:27,037 : INFO : topic #1 (0.167): 0.023*"quantum" + 0.011*"semiconductor" + 0.011*"semiconductors" + 0.010*"states" + 0.009*"energy" + 0.008*"spin" + 0.008*"results" + 0.008*"dots" + 0.006*"band" + 0.006*"interaction"
# 2020-05-06 04:32:27,040 : INFO : topic diff=0.722182, rho=0.577350
# 2020-05-06 04:32:30,145 : INFO : -7.924 per-word bound, 242.9 perplexity estimate based on a held-out corpus of 4222 documents with 189011 words
# 2020-05-06 04:32:30,150 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2020-05-06 04:32:33,132 : INFO : 3 accumulators retrieved from output queue
# 2020-05-06 04:32:33,152 : INFO : accumulated word occurrence stats for 4260 virtual documents
#  25%|██▌       | 5/20 [00:46<02:18,  9.26s/it]2020-05-06 04:32:33,361 : INFO : using symmetric alpha at 0.14285714285714285
# 2020-05-06 04:32:33,362 : INFO : using symmetric eta at 0.14285714285714285
# 2020-05-06 04:32:33,366 : INFO : using serial LDA version on this node
# 2020-05-06 04:32:33,382 : INFO : running online (single-pass) LDA training, 7 topics, 1 passes over the supplied corpus of 4222 documents, updating model once every 2000 documents, evaluating perplexity every 4222 documents, iterating 50x with a convergence threshold of 0.001000
# 2020-05-06 04:32:33,383 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2020-05-06 04:32:33,387 : INFO : PROGRESS: pass 0, at document #2000/4222
# 2020-05-06 04:32:35,324 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:32:35,331 : INFO : topic #6 (0.143): 0.012*"semiconductor" + 0.012*"field" + 0.011*"semiconductors" + 0.010*"spin" + 0.008*"quantum" + 0.007*"materials" + 0.006*"states" + 0.005*"effect" + 0.005*"effects" + 0.005*"state"
# 2020-05-06 04:32:35,332 : INFO : topic #4 (0.143): 0.014*"semiconductor" + 0.012*"quantum" + 0.009*"band" + 0.008*"spin" + 0.008*"charge" + 0.007*"properties" + 0.007*"field" + 0.006*"effect" + 0.006*"states" + 0.006*"system"
# 2020-05-06 04:32:35,333 : INFO : topic #0 (0.143): 0.010*"semiconductor" + 0.009*"band" + 0.007*"results" + 0.006*"states" + 0.006*"devices" + 0.005*"temperature" + 0.005*"electrons" + 0.005*"materials" + 0.005*"carriers" + 0.005*"field"
# 2020-05-06 04:32:35,335 : INFO : topic #5 (0.143): 0.016*"semiconductor" + 0.012*"energy" + 0.011*"semiconductors" + 0.008*"transition" + 0.007*"temperature" + 0.007*"model" + 0.007*"devices" + 0.007*"materials" + 0.006*"states" + 0.006*"band"
# 2020-05-06 04:32:35,336 : INFO : topic #3 (0.143): 0.011*"model" + 0.011*"band" + 0.010*"semiconductor" + 0.008*"field" + 0.008*"structure" + 0.008*"properties" + 0.008*"semiconductors" + 0.007*"materials" + 0.006*"results" + 0.006*"surface"
# 2020-05-06 04:32:35,336 : INFO : topic diff=5.109432, rho=1.000000
# 2020-05-06 04:32:35,338 : INFO : PROGRESS: pass 0, at document #4000/4222
# 2020-05-06 04:32:36,952 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:32:36,957 : INFO : topic #2 (0.143): 0.022*"spin" + 0.019*"semiconductor" + 0.016*"transport" + 0.015*"electron" + 0.012*"quantum" + 0.009*"effect" + 0.009*"properties" + 0.009*"field" + 0.009*"results" + 0.006*"semiconductors"
# 2020-05-06 04:32:36,960 : INFO : topic #6 (0.143): 0.018*"field" + 0.017*"spin" + 0.016*"semiconductor" + 0.011*"polarization" + 0.010*"semiconductors" + 0.009*"quantum" + 0.008*"effect" + 0.006*"states" + 0.006*"effects" + 0.006*"state"
# 2020-05-06 04:32:36,961 : INFO : topic #4 (0.143): 0.017*"semiconductor" + 0.017*"quantum" + 0.017*"spin" + 0.010*"field" + 0.009*"effect" + 0.008*"state" + 0.008*"electron" + 0.008*"interaction" + 0.007*"states" + 0.007*"system"
# 2020-05-06 04:32:36,963 : INFO : topic #3 (0.143): 0.015*"model" + 0.013*"band" + 0.011*"semiconductors" + 0.010*"semiconductor" + 0.010*"temperature" + 0.009*"field" + 0.009*"Mn" + 0.009*"structure" + 0.008*"results" + 0.007*"properties"
# 2020-05-06 04:32:36,965 : INFO : topic #0 (0.143): 0.011*"semiconductor" + 0.008*"band" + 0.007*"electrons" + 0.007*"states" + 0.007*"results" + 0.006*"temperature" + 0.005*"emission" + 0.005*"Majorana" + 0.005*"field" + 0.005*"carriers"
# 2020-05-06 04:32:36,966 : INFO : topic diff=0.934965, rho=0.707107
# 2020-05-06 04:32:37,186 : INFO : -8.262 per-word bound, 307.0 perplexity estimate based on a held-out corpus of 222 documents with 8091 words
# 2020-05-06 04:32:37,187 : INFO : PROGRESS: pass 0, at document #4222/4222
# 2020-05-06 04:32:37,365 : INFO : merging changes from 222 documents into a model of 4222 documents
# 2020-05-06 04:32:37,370 : INFO : topic #4 (0.143): 0.020*"quantum" + 0.018*"semiconductor" + 0.013*"field" + 0.013*"spin" + 0.011*"electron" + 0.010*"density" + 0.009*"interaction" + 0.009*"function" + 0.009*"electrons" + 0.008*"states"
# 2020-05-06 04:32:37,372 : INFO : topic #6 (0.143): 0.018*"field" + 0.015*"semiconductor" + 0.013*"spin" + 0.011*"semiconductors" + 0.010*"effect" + 0.008*"polarization" + 0.008*"quantum" + 0.008*"states" + 0.006*"temperature" + 0.006*"state"
# 2020-05-06 04:32:37,375 : INFO : topic #2 (0.143): 0.022*"semiconductor" + 0.016*"electron" + 0.015*"spin" + 0.015*"transport" + 0.013*"quantum" + 0.011*"field" + 0.010*"effect" + 0.009*"properties" + 0.008*"results" + 0.007*"temperature"
# 2020-05-06 04:32:37,376 : INFO : topic #5 (0.143): 0.020*"semiconductor" + 0.015*"energy" + 0.012*"semiconductors" + 0.012*"model" + 0.010*"temperature" + 0.010*"states" + 0.009*"superlattices" + 0.008*"transition" + 0.007*"superlattice" + 0.007*"theory"
# 2020-05-06 04:32:37,378 : INFO : topic #3 (0.143): 0.019*"model" + 0.014*"band" + 0.013*"surface" + 0.013*"temperature" + 0.011*"structure" + 0.011*"semiconductors" + 0.010*"results" + 0.010*"field" + 0.009*"semiconductor" + 0.008*"theory"
# 2020-05-06 04:32:37,380 : INFO : topic diff=0.720379, rho=0.577350
# 2020-05-06 04:32:40,834 : INFO : -7.983 per-word bound, 253.0 perplexity estimate based on a held-out corpus of 4222 documents with 189011 words
# 2020-05-06 04:32:40,838 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2020-05-06 04:32:43,856 : INFO : 3 accumulators retrieved from output queue
# 2020-05-06 04:32:43,875 : INFO : accumulated word occurrence stats for 4260 virtual documents
#  30%|███       | 6/20 [00:56<02:15,  9.71s/it]2020-05-06 04:32:44,111 : INFO : using symmetric alpha at 0.125
# 2020-05-06 04:32:44,112 : INFO : using symmetric eta at 0.125
# 2020-05-06 04:32:44,117 : INFO : using serial LDA version on this node
# 2020-05-06 04:32:44,127 : INFO : running online (single-pass) LDA training, 8 topics, 1 passes over the supplied corpus of 4222 documents, updating model once every 2000 documents, evaluating perplexity every 4222 documents, iterating 50x with a convergence threshold of 0.001000
# 2020-05-06 04:32:44,129 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2020-05-06 04:32:44,131 : INFO : PROGRESS: pass 0, at document #2000/4222
# 2020-05-06 04:32:45,767 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:32:45,772 : INFO : topic #5 (0.125): 0.015*"semiconductor" + 0.013*"energy" + 0.011*"semiconductors" + 0.008*"transition" + 0.007*"devices" + 0.007*"temperature" + 0.007*"model" + 0.007*"materials" + 0.007*"states" + 0.006*"band"
# 2020-05-06 04:32:45,773 : INFO : topic #2 (0.125): 0.015*"semiconductor" + 0.012*"properties" + 0.012*"spin" + 0.011*"quantum" + 0.011*"transport" + 0.009*"results" + 0.009*"electron" + 0.007*"semiconductors" + 0.007*"effect" + 0.007*"field"
# 2020-05-06 04:32:45,775 : INFO : topic #1 (0.125): 0.011*"quantum" + 0.011*"semiconductors" + 0.010*"semiconductor" + 0.010*"energy" + 0.008*"spin" + 0.008*"states" + 0.008*"band" + 0.007*"structure" + 0.006*"properties" + 0.006*"results"
# 2020-05-06 04:32:45,776 : INFO : topic #6 (0.125): 0.011*"semiconductor" + 0.011*"field" + 0.011*"spin" + 0.011*"semiconductors" + 0.008*"quantum" + 0.008*"materials" + 0.006*"states" + 0.005*"devices" + 0.005*"energy" + 0.005*"state"
# 2020-05-06 04:32:45,781 : INFO : topic #3 (0.125): 0.012*"model" + 0.011*"band" + 0.010*"semiconductor" + 0.009*"structure" + 0.008*"properties" + 0.008*"semiconductors" + 0.008*"field" + 0.008*"materials" + 0.007*"results" + 0.006*"temperature"
# 2020-05-06 04:32:45,782 : INFO : topic diff=5.873702, rho=1.000000
# 2020-05-06 04:32:45,785 : INFO : PROGRESS: pass 0, at document #4000/4222
# 2020-05-06 04:32:47,247 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:32:47,252 : INFO : topic #5 (0.125): 0.018*"semiconductor" + 0.013*"energy" + 0.011*"semiconductors" + 0.009*"temperature" + 0.008*"model" + 0.007*"states" + 0.007*"transition" + 0.006*"theory" + 0.006*"exciton" + 0.005*"materials"
# 2020-05-06 04:32:47,253 : INFO : topic #6 (0.125): 0.020*"spin" + 0.018*"field" + 0.016*"semiconductor" + 0.013*"polarization" + 0.010*"semiconductors" + 0.009*"quantum" + 0.007*"effect" + 0.006*"effects" + 0.006*"states" + 0.006*"state"
# 2020-05-06 04:32:47,255 : INFO : topic #0 (0.125): 0.011*"semiconductor" + 0.007*"states" + 0.007*"Majorana" + 0.007*"emission" + 0.007*"results" + 0.007*"electrons" + 0.007*"band" + 0.006*"field" + 0.005*"temperature" + 0.004*"carriers"
# 2020-05-06 04:32:47,257 : INFO : topic #7 (0.125): 0.017*"semiconductor" + 0.012*"field" + 0.011*"effect" + 0.008*"semiconductors" + 0.008*"electron" + 0.007*"transport" + 0.007*"interface" + 0.006*"energy" + 0.005*"temperature" + 0.005*"effects"
# 2020-05-06 04:32:47,258 : INFO : topic #4 (0.125): 0.018*"quantum" + 0.018*"semiconductor" + 0.016*"spin" + 0.009*"field" + 0.009*"effect" + 0.008*"state" + 0.008*"states" + 0.008*"interaction" + 0.008*"electron" + 0.008*"system"
# 2020-05-06 04:32:47,259 : INFO : topic diff=0.842504, rho=0.707107
# 2020-05-06 04:32:47,449 : INFO : -8.381 per-word bound, 333.4 perplexity estimate based on a held-out corpus of 222 documents with 8091 words
# 2020-05-06 04:32:47,450 : INFO : PROGRESS: pass 0, at document #4222/4222
# 2020-05-06 04:32:47,587 : INFO : merging changes from 222 documents into a model of 4222 documents
# 2020-05-06 04:32:47,593 : INFO : topic #4 (0.125): 0.021*"quantum" + 0.018*"semiconductor" + 0.013*"field" + 0.012*"spin" + 0.011*"density" + 0.011*"electron" + 0.010*"interaction" + 0.010*"function" + 0.009*"electrons" + 0.009*"states"
# 2020-05-06 04:32:47,594 : INFO : topic #2 (0.125): 0.023*"semiconductor" + 0.018*"electron" + 0.017*"spin" + 0.016*"transport" + 0.012*"quantum" + 0.012*"field" + 0.011*"effect" + 0.009*"results" + 0.009*"properties" + 0.007*"temperature"
# 2020-05-06 04:32:47,596 : INFO : topic #1 (0.125): 0.027*"quantum" + 0.013*"states" + 0.011*"semiconductor" + 0.011*"energy" + 0.011*"semiconductors" + 0.008*"dots" + 0.008*"structure" + 0.008*"spin" + 0.008*"band" + 0.007*"exchange"
# 2020-05-06 04:32:47,598 : INFO : topic #7 (0.125): 0.017*"interface" + 0.015*"semiconductor" + 0.011*"field" + 0.010*"effect" + 0.009*"semiconductors" + 0.009*"interfaces" + 0.007*"transport" + 0.007*"electron" + 0.006*"surface" + 0.006*"model"
# 2020-05-06 04:32:47,599 : INFO : topic #5 (0.125): 0.018*"semiconductor" + 0.015*"energy" + 0.012*"semiconductors" + 0.011*"model" + 0.011*"states" + 0.008*"temperature" + 0.008*"superlattices" + 0.007*"transition" + 0.006*"theory" + 0.006*"equations"
# 2020-05-06 04:32:47,601 : INFO : topic diff=0.690672, rho=0.577350
# 2020-05-06 04:32:50,879 : INFO : -8.040 per-word bound, 263.3 perplexity estimate based on a held-out corpus of 4222 documents with 189011 words
# 2020-05-06 04:32:50,884 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2020-05-06 04:32:54,062 : INFO : 3 accumulators retrieved from output queue
# 2020-05-06 04:32:54,117 : INFO : accumulated word occurrence stats for 4272 virtual documents
#  35%|███▌      | 7/20 [01:07<02:08,  9.90s/it]2020-05-06 04:32:54,453 : INFO : using symmetric alpha at 0.1111111111111111
# 2020-05-06 04:32:54,455 : INFO : using symmetric eta at 0.1111111111111111
# 2020-05-06 04:32:54,458 : INFO : using serial LDA version on this node
# 2020-05-06 04:32:54,471 : INFO : running online (single-pass) LDA training, 9 topics, 1 passes over the supplied corpus of 4222 documents, updating model once every 2000 documents, evaluating perplexity every 4222 documents, iterating 50x with a convergence threshold of 0.001000
# 2020-05-06 04:32:54,472 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2020-05-06 04:32:54,474 : INFO : PROGRESS: pass 0, at document #2000/4222
# 2020-05-06 04:32:56,031 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:32:56,037 : INFO : topic #6 (0.111): 0.012*"semiconductor" + 0.012*"field" + 0.011*"spin" + 0.011*"semiconductors" + 0.008*"quantum" + 0.008*"materials" + 0.007*"states" + 0.005*"state" + 0.005*"transition" + 0.005*"polarization"
# 2020-05-06 04:32:56,038 : INFO : topic #8 (0.111): 0.010*"semiconductor" + 0.009*"quantum" + 0.008*"coupling" + 0.008*"devices" + 0.008*"properties" + 0.007*"band" + 0.007*"semiconductors" + 0.007*"materials" + 0.006*"applications" + 0.006*"states"
# 2020-05-06 04:32:56,039 : INFO : topic #1 (0.111): 0.011*"semiconductors" + 0.011*"quantum" + 0.011*"energy" + 0.010*"semiconductor" + 0.008*"spin" + 0.008*"states" + 0.008*"band" + 0.007*"temperature" + 0.006*"results" + 0.006*"properties"
# 2020-05-06 04:32:56,040 : INFO : topic #4 (0.111): 0.014*"semiconductor" + 0.013*"quantum" + 0.009*"spin" + 0.008*"band" + 0.008*"charge" + 0.007*"properties" + 0.007*"states" + 0.007*"field" + 0.006*"effect" + 0.006*"semiconductors"
# 2020-05-06 04:32:56,042 : INFO : topic #2 (0.111): 0.015*"semiconductor" + 0.014*"spin" + 0.013*"properties" + 0.011*"transport" + 0.011*"quantum" + 0.009*"results" + 0.009*"electron" + 0.007*"semiconductors" + 0.007*"effect" + 0.006*"field"
# 2020-05-06 04:32:56,043 : INFO : topic diff=6.618641, rho=1.000000
# 2020-05-06 04:32:56,045 : INFO : PROGRESS: pass 0, at document #4000/4222
# 2020-05-06 04:32:57,514 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:32:57,520 : INFO : topic #4 (0.111): 0.018*"quantum" + 0.018*"spin" + 0.018*"semiconductor" + 0.010*"field" + 0.008*"effect" + 0.008*"interaction" + 0.008*"state" + 0.008*"states" + 0.007*"coupling" + 0.007*"electron"
# 2020-05-06 04:32:57,521 : INFO : topic #7 (0.111): 0.018*"semiconductor" + 0.015*"field" + 0.012*"effect" + 0.009*"transport" + 0.009*"semiconductors" + 0.008*"interface" + 0.008*"electron" + 0.006*"band" + 0.006*"energy" + 0.006*"Hall"
# 2020-05-06 04:32:57,523 : INFO : topic #8 (0.111): 0.013*"semiconductor" + 0.012*"quantum" + 0.009*"devices" + 0.008*"coupling" + 0.007*"electron" + 0.007*"properties" + 0.006*"state" + 0.006*"semiconductors" + 0.006*"states" + 0.005*"results"
# 2020-05-06 04:32:57,524 : INFO : topic #3 (0.111): 0.017*"model" + 0.012*"band" + 0.011*"semiconductors" + 0.011*"semiconductor" + 0.010*"field" + 0.010*"temperature" + 0.009*"Mn" + 0.008*"structure" + 0.008*"results" + 0.007*"properties"
# 2020-05-06 04:32:57,525 : INFO : topic #0 (0.111): 0.012*"semiconductor" + 0.009*"electrons" + 0.007*"results" + 0.007*"field" + 0.006*"band" + 0.006*"temperature" + 0.005*"states" + 0.005*"Majorana" + 0.005*"energy" + 0.005*"scattering"
# 2020-05-06 04:32:57,527 : INFO : topic diff=0.780964, rho=0.707107
# 2020-05-06 04:32:57,697 : INFO : -8.505 per-word bound, 363.4 perplexity estimate based on a held-out corpus of 222 documents with 8091 words
# 2020-05-06 04:32:57,698 : INFO : PROGRESS: pass 0, at document #4222/4222
# 2020-05-06 04:32:57,832 : INFO : merging changes from 222 documents into a model of 4222 documents
# 2020-05-06 04:32:57,838 : INFO : topic #3 (0.111): 0.023*"model" + 0.013*"field" + 0.013*"band" + 0.013*"surface" + 0.012*"temperature" + 0.011*"structure" + 0.011*"results" + 0.010*"semiconductors" + 0.010*"semiconductor" + 0.008*"theory"
# 2020-05-06 04:32:57,839 : INFO : topic #7 (0.111): 0.025*"interface" + 0.016*"semiconductor" + 0.013*"effect" + 0.012*"field" + 0.010*"semiconductors" + 0.009*"transport" + 0.008*"interfaces" + 0.007*"model" + 0.006*"electron" + 0.006*"paper"
# 2020-05-06 04:32:57,840 : INFO : topic #4 (0.111): 0.022*"quantum" + 0.018*"semiconductor" + 0.013*"field" + 0.013*"spin" + 0.011*"density" + 0.010*"electron" + 0.010*"function" + 0.009*"interaction" + 0.009*"electrons" + 0.009*"system"
# 2020-05-06 04:32:57,841 : INFO : topic #2 (0.111): 0.024*"semiconductor" + 0.019*"electron" + 0.019*"spin" + 0.016*"transport" + 0.014*"quantum" + 0.012*"effect" + 0.011*"field" + 0.009*"properties" + 0.009*"results" + 0.007*"temperature"
# 2020-05-06 04:32:57,843 : INFO : topic #8 (0.111): 0.012*"semiconductor" + 0.011*"quantum" + 0.011*"surface" + 0.008*"CDW" + 0.008*"coupling" + 0.007*"structures" + 0.007*"states" + 0.006*"system" + 0.006*"temperature" + 0.006*"electron"
# 2020-05-06 04:32:57,844 : INFO : topic diff=0.662898, rho=0.577350
# 2020-05-06 04:33:00,704 : INFO : -8.109 per-word bound, 276.0 perplexity estimate based on a held-out corpus of 4222 documents with 189011 words
# 2020-05-06 04:33:00,708 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2020-05-06 04:33:03,591 : INFO : 3 accumulators retrieved from output queue
# 2020-05-06 04:33:03,616 : INFO : accumulated word occurrence stats for 4271 virtual documents
#  40%|████      | 8/20 [01:16<01:57,  9.77s/it]2020-05-06 04:33:03,912 : INFO : using symmetric alpha at 0.1
# 2020-05-06 04:33:03,913 : INFO : using symmetric eta at 0.1
# 2020-05-06 04:33:03,917 : INFO : using serial LDA version on this node
# 2020-05-06 04:33:03,929 : INFO : running online (single-pass) LDA training, 10 topics, 1 passes over the supplied corpus of 4222 documents, updating model once every 2000 documents, evaluating perplexity every 4222 documents, iterating 50x with a convergence threshold of 0.001000
# 2020-05-06 04:33:03,930 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2020-05-06 04:33:03,932 : INFO : PROGRESS: pass 0, at document #2000/4222
# 2020-05-06 04:33:05,369 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:33:05,375 : INFO : topic #2 (0.100): 0.016*"semiconductor" + 0.015*"spin" + 0.011*"properties" + 0.011*"transport" + 0.010*"quantum" + 0.010*"results" + 0.009*"electron" + 0.008*"effect" + 0.007*"field" + 0.007*"semiconductors"
# 2020-05-06 04:33:05,375 : INFO : topic #8 (0.100): 0.011*"semiconductor" + 0.009*"coupling" + 0.009*"quantum" + 0.008*"devices" + 0.007*"semiconductors" + 0.007*"band" + 0.007*"properties" + 0.007*"states" + 0.006*"electron" + 0.006*"applications"
# 2020-05-06 04:33:05,377 : INFO : topic #5 (0.100): 0.016*"semiconductor" + 0.014*"energy" + 0.011*"semiconductors" + 0.008*"transition" + 0.007*"model" + 0.006*"temperature" + 0.006*"devices" + 0.006*"states" + 0.006*"materials" + 0.005*"band"
# 2020-05-06 04:33:05,378 : INFO : topic #1 (0.100): 0.011*"semiconductors" + 0.010*"energy" + 0.010*"semiconductor" + 0.009*"quantum" + 0.009*"spin" + 0.008*"states" + 0.008*"band" + 0.006*"interaction" + 0.006*"structure" + 0.006*"charge"
# 2020-05-06 04:33:05,379 : INFO : topic #7 (0.100): 0.015*"semiconductor" + 0.012*"field" + 0.009*"effect" + 0.008*"semiconductors" + 0.006*"electron" + 0.006*"transport" + 0.006*"energy" + 0.006*"band" + 0.006*"effects" + 0.005*"charge"
# 2020-05-06 04:33:05,380 : INFO : topic diff=7.385711, rho=1.000000
# 2020-05-06 04:33:05,382 : INFO : PROGRESS: pass 0, at document #4000/4222
# 2020-05-06 04:33:06,787 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:33:06,793 : INFO : topic #9 (0.100): 0.016*"semiconductor" + 0.012*"materials" + 0.012*"temperature" + 0.010*"band" + 0.010*"quantum" + 0.009*"properties" + 0.009*"system" + 0.008*"semiconductors" + 0.007*"structure" + 0.007*"theory"
# 2020-05-06 04:33:06,793 : INFO : topic #0 (0.100): 0.012*"semiconductor" + 0.009*"states" + 0.008*"Majorana" + 0.007*"electrons" + 0.007*"band" + 0.006*"results" + 0.006*"field" + 0.006*"energy" + 0.006*"temperature" + 0.005*"gap"
# 2020-05-06 04:33:06,794 : INFO : topic #8 (0.100): 0.014*"semiconductor" + 0.012*"quantum" + 0.009*"coupling" + 0.008*"electron" + 0.007*"devices" + 0.007*"state" + 0.007*"states" + 0.006*"semiconductors" + 0.006*"properties" + 0.006*"energy"
# 2020-05-06 04:33:06,797 : INFO : topic #3 (0.100): 0.017*"model" + 0.012*"band" + 0.011*"semiconductors" + 0.011*"temperature" + 0.010*"field" + 0.010*"Mn" + 0.010*"semiconductor" + 0.009*"results" + 0.008*"structure" + 0.007*"theory"
# 2020-05-06 04:33:06,798 : INFO : topic #6 (0.100): 0.020*"spin" + 0.019*"field" + 0.017*"semiconductor" + 0.014*"polarization" + 0.012*"semiconductors" + 0.010*"quantum" + 0.008*"effect" + 0.007*"states" + 0.006*"effects" + 0.006*"state"
# 2020-05-06 04:33:06,799 : INFO : topic diff=0.737586, rho=0.707107
# 2020-05-06 04:33:06,982 : INFO : -8.627 per-word bound, 395.2 perplexity estimate based on a held-out corpus of 222 documents with 8091 words
# 2020-05-06 04:33:06,983 : INFO : PROGRESS: pass 0, at document #4222/4222
# 2020-05-06 04:33:07,130 : INFO : merging changes from 222 documents into a model of 4222 documents
# 2020-05-06 04:33:07,139 : INFO : topic #8 (0.100): 0.017*"quantum" + 0.012*"semiconductor" + 0.012*"states" + 0.010*"surface" + 0.009*"coupling" + 0.009*"structures" + 0.009*"CDW" + 0.007*"state" + 0.006*"field" + 0.006*"electron"
# 2020-05-06 04:33:07,141 : INFO : topic #2 (0.100): 0.024*"semiconductor" + 0.022*"spin" + 0.021*"electron" + 0.016*"transport" + 0.016*"field" + 0.014*"quantum" + 0.014*"effect" + 0.010*"results" + 0.008*"properties" + 0.007*"devices"
# 2020-05-06 04:33:07,142 : INFO : topic #7 (0.100): 0.023*"interface" + 0.015*"semiconductor" + 0.014*"field" + 0.013*"effect" + 0.010*"interfaces" + 0.009*"semiconductors" + 0.008*"Phys" + 0.007*"Rev" + 0.007*"model" + 0.006*"transport"
# 2020-05-06 04:33:07,144 : INFO : topic #1 (0.100): 0.022*"quantum" + 0.013*"semiconductors" + 0.012*"states" + 0.012*"spin" + 0.011*"energy" + 0.010*"semiconductor" + 0.010*"exchange" + 0.008*"results" + 0.007*"band" + 0.007*"interaction"
# 2020-05-06 04:33:07,145 : INFO : topic #9 (0.100): 0.017*"semiconductor" + 0.014*"band" + 0.014*"temperature" + 0.011*"system" + 0.010*"quantum" + 0.010*"states" + 0.009*"semiconductors" + 0.009*"properties" + 0.009*"structure" + 0.009*"model"
# 2020-05-06 04:33:07,149 : INFO : topic diff=0.642825, rho=0.577350
# 2020-05-06 04:33:10,492 : INFO : -8.176 per-word bound, 289.2 perplexity estimate based on a held-out corpus of 4222 documents with 189011 words
# 2020-05-06 04:33:10,496 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2020-05-06 04:33:13,263 : INFO : 3 accumulators retrieved from output queue
# 2020-05-06 04:33:13,284 : INFO : accumulated word occurrence stats for 4274 virtual documents
#  45%|████▌     | 9/20 [01:26<01:47,  9.75s/it]2020-05-06 04:33:13,617 : INFO : using symmetric alpha at 0.09090909090909091
# 2020-05-06 04:33:13,618 : INFO : using symmetric eta at 0.09090909090909091
# 2020-05-06 04:33:13,622 : INFO : using serial LDA version on this node
# 2020-05-06 04:33:13,636 : INFO : running online (single-pass) LDA training, 11 topics, 1 passes over the supplied corpus of 4222 documents, updating model once every 2000 documents, evaluating perplexity every 4222 documents, iterating 50x with a convergence threshold of 0.001000
# 2020-05-06 04:33:13,637 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2020-05-06 04:33:13,641 : INFO : PROGRESS: pass 0, at document #2000/4222
# 2020-05-06 04:33:15,149 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:33:15,156 : INFO : topic #4 (0.091): 0.014*"semiconductor" + 0.012*"quantum" + 0.009*"spin" + 0.008*"band" + 0.008*"charge" + 0.007*"properties" + 0.007*"states" + 0.007*"field" + 0.007*"effect" + 0.006*"semiconductors"
# 2020-05-06 04:33:15,158 : INFO : topic #5 (0.091): 0.017*"semiconductor" + 0.012*"semiconductors" + 0.012*"energy" + 0.009*"transition" + 0.007*"model" + 0.006*"states" + 0.006*"temperature" + 0.006*"devices" + 0.006*"band" + 0.006*"materials"
# 2020-05-06 04:33:15,163 : INFO : topic #7 (0.091): 0.016*"semiconductor" + 0.012*"field" + 0.008*"semiconductors" + 0.007*"effect" + 0.007*"transport" + 0.007*"band" + 0.006*"electron" + 0.006*"effects" + 0.006*"energy" + 0.005*"state"
# 2020-05-06 04:33:15,164 : INFO : topic #6 (0.091): 0.013*"spin" + 0.013*"field" + 0.012*"semiconductors" + 0.012*"semiconductor" + 0.007*"materials" + 0.007*"quantum" + 0.007*"states" + 0.006*"state" + 0.005*"effect" + 0.005*"effects"
# ...
# 2020-05-06 04:34:39,206 : INFO : topic #11 (0.053): 0.014*"semiconductor" + 0.012*"semiconductors" + 0.010*"properties" + 0.009*"materials" + 0.009*"field" + 0.007*"band" + 0.007*"temperature" + 0.007*"density" + 0.007*"devices" + 0.007*"results"
# 2020-05-06 04:34:39,207 : INFO : topic #17 (0.053): 0.013*"band" + 0.010*"semiconductor" + 0.010*"properties" + 0.008*"energy" + 0.008*"states" + 0.008*"semiconductors" + 0.007*"transport" + 0.007*"temperature" + 0.007*"materials" + 0.007*"structure"
# 2020-05-06 04:34:39,210 : INFO : topic #15 (0.053): 0.013*"semiconductor" + 0.008*"devices" + 0.008*"model" + 0.008*"band" + 0.007*"theory" + 0.006*"charge" + 0.006*"semiconductors" + 0.005*"behavior" + 0.005*"exciton" + 0.005*"frequency"
# 2020-05-06 04:34:39,212 : INFO : topic #18 (0.053): 0.011*"semiconductor" + 0.010*"energy" + 0.007*"absorption" + 0.007*"Fe" + 0.007*"states" + 0.007*"field" + 0.007*"effect" + 0.007*"charge" + 0.007*"model" + 0.007*"band"
# 2020-05-06 04:34:39,213 : INFO : topic diff=14.902940, rho=1.000000
# 2020-05-06 04:34:39,217 : INFO : PROGRESS: pass 0, at document #4000/4222
# 2020-05-06 04:34:40,611 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:34:40,623 : INFO : topic #12 (0.053): 0.020*"semiconductor" + 0.009*"quantum" + 0.008*"power" + 0.008*"theory" + 0.007*"model" + 0.007*"semiconductors" + 0.007*"exciton" + 0.007*"results" + 0.007*"disorder" + 0.005*"band"
# 2020-05-06 04:34:40,624 : INFO : topic #6 (0.053): 0.032*"spin" + 0.024*"field" + 0.018*"polarization" + 0.016*"semiconductor" + 0.013*"semiconductors" + 0.011*"quantum" + 0.010*"state" + 0.009*"relaxation" + 0.009*"states" + 0.008*"effect"
# 2020-05-06 04:34:40,627 : INFO : topic #7 (0.053): 0.018*"semiconductor" + 0.018*"field" + 0.012*"effect" + 0.011*"electron" + 0.009*"transport" + 0.008*"effects" + 0.008*"Phys" + 0.007*"magnetoresistance" + 0.007*"spin" + 0.007*"Rev"
# 2020-05-06 04:34:40,630 : INFO : topic #9 (0.053): 0.019*"quantum" + 0.015*"semiconductor" + 0.014*"materials" + 0.013*"system" + 0.009*"properties" + 0.009*"temperature" + 0.008*"semiconductors" + 0.008*"band" + 0.007*"model" + 0.006*"structure"
# 2020-05-06 04:34:40,632 : INFO : topic #1 (0.053): 0.017*"exchange" + 0.016*"spin" + 0.014*"semiconductors" + 0.013*"quantum" + 0.012*"states" + 0.012*"interaction" + 0.012*"semiconductor" + 0.011*"Mn" + 0.010*"energy" + 0.007*"band"
# 2020-05-06 04:34:40,633 : INFO : topic diff=0.677321, rho=0.707107
# 2020-05-06 04:34:40,853 : INFO : -9.535 per-word bound, 742.0 perplexity estimate based on a held-out corpus of 222 documents with 8091 words
# 2020-05-06 04:34:40,854 : INFO : PROGRESS: pass 0, at document #4222/4222
# 2020-05-06 04:34:41,020 : INFO : merging changes from 222 documents into a model of 4222 documents
# 2020-05-06 04:34:41,030 : INFO : topic #12 (0.053): 0.022*"semiconductor" + 0.012*"spectra" + 0.012*"laser" + 0.010*"power" + 0.010*"emission" + 0.009*"absorption" + 0.009*"quantum" + 0.009*"spectrum" + 0.008*"wavelength" + 0.008*"system"
# 2020-05-06 04:34:41,031 : INFO : topic #15 (0.053): 0.024*"mode" + 0.022*"frequency" + 0.021*"laser" + 0.018*"semiconductor" + 0.013*"responsivity" + 0.011*"superlattice" + 0.009*"SHG" + 0.009*"plasma" + 0.008*"model" + 0.008*"dielectric"
# 2020-05-06 04:34:41,032 : INFO : topic #7 (0.053): 0.018*"field" + 0.017*"semiconductor" + 0.011*"electron" + 0.011*"effect" + 0.010*"Phys" + 0.010*"island" + 0.010*"magnetoresistance" + 0.010*"Rev" + 0.010*"transport" + 0.010*"semiconductors"
# 2020-05-06 04:34:41,034 : INFO : topic #9 (0.053): 0.019*"quantum" + 0.018*"semiconductor" + 0.014*"system" + 0.010*"properties" + 0.010*"density" + 0.010*"materials" + 0.009*"theory" + 0.008*"temperature" + 0.008*"structure" + 0.007*"electrons"
# 2020-05-06 04:34:41,035 : INFO : topic #14 (0.053): 0.021*"fields" + 0.020*"field" + 0.015*"spin" + 0.014*"effect" + 0.012*"dislocation" + 0.010*"results" + 0.009*"semiconductors" + 0.009*"carriers" + 0.009*"injection" + 0.009*"strain"
# 2020-05-06 04:34:41,036 : INFO : topic diff=0.634843, rho=0.577350
# 2020-05-06 04:34:44,014 : INFO : -8.612 per-word bound, 391.2 perplexity estimate based on a held-out corpus of 4222 documents with 189011 words
# 2020-05-06 04:34:44,020 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2020-05-06 04:34:47,192 : INFO : 3 accumulators retrieved from output queue
# 2020-05-06 04:34:47,232 : INFO : accumulated word occurrence stats for 4273 virtual documents
#  90%|█████████ | 18/20 [03:00<00:21, 10.57s/it]2020-05-06 04:34:47,849 : INFO : using symmetric alpha at 0.05
# 2020-05-06 04:34:47,850 : INFO : using symmetric eta at 0.05
# 2020-05-06 04:34:47,854 : INFO : using serial LDA version on this node
# 2020-05-06 04:34:47,880 : INFO : running online (single-pass) LDA training, 20 topics, 1 passes over the supplied corpus of 4222 documents, updating model once every 2000 documents, evaluating perplexity every 4222 documents, iterating 50x with a convergence threshold of 0.001000
# 2020-05-06 04:34:47,881 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2020-05-06 04:34:47,883 : INFO : PROGRESS: pass 0, at document #2000/4222
# 2020-05-06 04:34:49,280 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:34:49,292 : INFO : topic #6 (0.050): 0.016*"spin" + 0.013*"semiconductors" + 0.013*"field" + 0.012*"semiconductor" + 0.008*"states" + 0.008*"materials" + 0.008*"quantum" + 0.006*"effect" + 0.006*"polarization" + 0.006*"state"
# 2020-05-06 04:34:49,294 : INFO : topic #8 (0.050): 0.013*"coupling" + 0.010*"semiconductor" + 0.010*"quantum" + 0.009*"devices" + 0.008*"states" + 0.007*"semiconductors" + 0.007*"state" + 0.006*"properties" + 0.006*"field" + 0.006*"temperature"
# 2020-05-06 04:34:49,296 : INFO : topic #17 (0.050): 0.011*"semiconductor" + 0.010*"band" + 0.010*"states" + 0.008*"quantum" + 0.008*"materials" + 0.008*"temperature" + 0.007*"semiconductors" + 0.007*"properties" + 0.007*"structure" + 0.007*"energy"
# 2020-05-06 04:34:49,299 : INFO : topic #11 (0.050): 0.015*"semiconductor" + 0.011*"semiconductors" + 0.010*"properties" + 0.009*"materials" + 0.009*"field" + 0.007*"applications" + 0.007*"temperature" + 0.007*"devices" + 0.006*"structure" + 0.006*"density"
# 2020-05-06 04:34:49,307 : INFO : topic #0 (0.050): 0.011*"semiconductor" + 0.007*"electrons" + 0.006*"states" + 0.006*"results" + 0.005*"band" + 0.005*"field" + 0.005*"regime" + 0.005*"Majorana" + 0.005*"scattering" + 0.005*"%"
# 2020-05-06 04:34:49,310 : INFO : topic diff=15.791668, rho=1.000000
# 2020-05-06 04:34:49,313 : INFO : PROGRESS: pass 0, at document #4000/4222
# 2020-05-06 04:34:50,491 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:34:50,502 : INFO : topic #7 (0.050): 0.018*"field" + 0.017*"semiconductor" + 0.012*"effect" + 0.010*"electron" + 0.008*"semiconductors" + 0.007*"model" + 0.007*"state" + 0.007*"Phys" + 0.007*"quantum" + 0.007*"interface"
# 2020-05-06 04:34:50,508 : INFO : topic #3 (0.050): 0.022*"model" + 0.015*"Mn" + 0.012*"field" + 0.012*"semiconductors" + 0.011*"Ga" + 0.011*"temperature" + 0.010*"band" + 0.010*"semiconductor" + 0.009*"theory" + 0.008*"structure"
# 2020-05-06 04:34:50,509 : INFO : topic #1 (0.050): 0.018*"quantum" + 0.017*"spin" + 0.016*"exchange" + 0.013*"interaction" + 0.012*"semiconductors" + 0.012*"Mn" + 0.012*"semiconductor" + 0.011*"energy" + 0.010*"states" + 0.008*"dots"
# 2020-05-06 04:34:50,511 : INFO : topic #4 (0.050): 0.020*"spin" + 0.019*"quantum" + 0.018*"semiconductor" + 0.013*"field" + 0.010*"effect" + 0.009*"coupling" + 0.009*"state" + 0.009*"Mn" + 0.008*"interaction" + 0.008*"system"
# 2020-05-06 04:34:50,512 : INFO : topic #6 (0.050): 0.030*"spin" + 0.021*"field" + 0.017*"polarization" + 0.017*"semiconductor" + 0.013*"semiconductors" + 0.011*"effect" + 0.010*"quantum" + 0.008*"states" + 0.008*"time" + 0.008*"state"
# 2020-05-06 04:34:50,513 : INFO : topic diff=0.669307, rho=0.707107
# 2020-05-06 04:34:50,694 : INFO : -9.622 per-word bound, 788.0 perplexity estimate based on a held-out corpus of 222 documents with 8091 words
# 2020-05-06 04:34:50,695 : INFO : PROGRESS: pass 0, at document #4222/4222
# 2020-05-06 04:34:50,830 : INFO : merging changes from 222 documents into a model of 4222 documents
# 2020-05-06 04:34:50,842 : INFO : topic #5 (0.050): 0.022*"semiconductor" + 0.019*"energy" + 0.016*"superlattices" + 0.015*"model" + 0.012*"equations" + 0.011*"semiconductors" + 0.011*"temperature" + 0.009*"phase" + 0.009*"barrier" + 0.008*"oscillations"
# 2020-05-06 04:34:50,843 : INFO : topic #0 (0.050): 0.015*"semiconductor" + 0.013*"electrons" + 0.013*"fermions" + 0.012*"conductance" + 0.010*"scattering" + 0.010*"dc" + 0.010*"field" + 0.008*"peak" + 0.008*"multistability" + 0.007*"bias"
# 2020-05-06 04:34:50,845 : INFO : topic #1 (0.050): 0.021*"exchange" + 0.019*"quantum" + 0.017*"interaction" + 0.015*"semiconductors" + 0.014*"spin" + 0.013*"states" + 0.012*"exciton" + 0.012*"density" + 0.010*"semiconductor" + 0.010*"results"
# 2020-05-06 04:34:50,851 : INFO : topic #12 (0.050): 0.023*"localization" + 0.021*"semiconductor" + 0.020*"laser" + 0.013*"layers" + 0.011*"emission" + 0.010*"spectra" + 0.010*"disorder" + 0.010*"line" + 0.009*"quantum" + 0.009*"power"
# 2020-05-06 04:34:50,853 : INFO : topic #6 (0.050): 0.029*"spin" + 0.028*"field" + 0.015*"polarization" + 0.015*"semiconductor" + 0.013*"effect" + 0.012*"quantum" + 0.011*"semiconductors" + 0.011*"Hall" + 0.010*"states" + 0.008*"electron"
# 2020-05-06 04:34:50,855 : INFO : topic diff=0.616906, rho=0.577350
# 2020-05-06 04:34:53,518 : INFO : -8.654 per-word bound, 402.8 perplexity estimate based on a held-out corpus of 4222 documents with 189011 words
# 2020-05-06 04:34:53,525 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2020-05-06 04:34:56,530 : INFO : 3 accumulators retrieved from output queue
# 2020-05-06 04:34:56,575 : INFO : accumulated word occurrence stats for 4274 virtual documents
#  95%|█████████▌| 19/20 [03:10<00:10, 10.21s/it]2020-05-06 04:34:57,232 : INFO : using symmetric alpha at 0.047619047619047616
# 2020-05-06 04:34:57,233 : INFO : using symmetric eta at 0.047619047619047616
# 2020-05-06 04:34:57,238 : INFO : using serial LDA version on this node
# 2020-05-06 04:34:57,264 : INFO : running online (single-pass) LDA training, 21 topics, 1 passes over the supplied corpus of 4222 documents, updating model once every 2000 documents, evaluating perplexity every 4222 documents, iterating 50x with a convergence threshold of 0.001000
# 2020-05-06 04:34:57,265 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2020-05-06 04:34:57,267 : INFO : PROGRESS: pass 0, at document #2000/4222
# 2020-05-06 04:34:58,668 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:34:58,681 : INFO : topic #12 (0.048): 0.017*"semiconductor" + 0.009*"theory" + 0.008*"model" + 0.008*"semiconductors" + 0.008*"results" + 0.007*"band" + 0.007*"quantum" + 0.007*"materials" + 0.006*"disorder" + 0.006*"effect"
# 2020-05-06 04:34:58,682 : INFO : topic #16 (0.048): 0.014*"semiconductor" + 0.010*"semiconductors" + 0.009*"energy" + 0.008*"spin" + 0.006*"field" + 0.006*"effects" + 0.006*"model" + 0.006*"materials" + 0.006*"results" + 0.005*"quantum"
# 2020-05-06 04:34:58,683 : INFO : topic #18 (0.048): 0.011*"semiconductor" + 0.010*"energy" + 0.008*"model" + 0.007*"field" + 0.007*"band" + 0.006*"states" + 0.006*"analysis" + 0.006*"effect" + 0.006*"charge" + 0.006*"results"
# 2020-05-06 04:34:58,688 : INFO : topic #15 (0.048): 0.011*"semiconductor" + 0.009*"band" + 0.008*"model" + 0.007*"theory" + 0.007*"order" + 0.007*"charge" + 0.006*"devices" + 0.006*"semiconductors" + 0.006*"carrier" + 0.006*"density"
# 2020-05-06 04:34:58,690 : INFO : topic #14 (0.048): 0.014*"field" + 0.013*"spin" + 0.013*"properties" + 0.009*"band" + 0.008*"results" + 0.007*"gap" + 0.007*"structure" + 0.007*"semiconductors" + 0.006*"effect" + 0.006*"dynamics"
# 2020-05-06 04:34:58,692 : INFO : topic diff=16.669891, rho=1.000000
# 2020-05-06 04:34:58,695 : INFO : PROGRESS: pass 0, at document #4000/4222
# 2020-05-06 04:34:59,870 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:34:59,882 : INFO : topic #13 (0.048): 0.022*"semiconductor" + 0.013*"states" + 0.010*"quantum" + 0.009*"interaction" + 0.008*"properties" + 0.008*"transport" + 0.008*"energy" + 0.008*"temperature" + 0.008*"electron" + 0.007*"Majorana"
# 2020-05-06 04:34:59,884 : INFO : topic #19 (0.048): 0.034*"band" + 0.017*"semiconductors" + 0.014*"Mn" + 0.013*"valence" + 0.010*"energy" + 0.010*"semiconductor" + 0.010*"model" + 0.009*"temperature" + 0.008*"results" + 0.007*"conduction"
# 2020-05-06 04:34:59,885 : INFO : topic #11 (0.048): 0.017*"semiconductor" + 0.012*"semiconductors" + 0.011*"field" + 0.009*"properties" + 0.008*"structure" + 0.007*"materials" + 0.007*"temperature" + 0.007*"results" + 0.007*"surface" + 0.006*"density"
# 2020-05-06 04:34:59,886 : INFO : topic #1 (0.048): 0.018*"quantum" + 0.018*"exchange" + 0.016*"Mn" + 0.014*"spin" + 0.014*"semiconductors" + 0.014*"interaction" + 0.012*"states" + 0.011*"energy" + 0.010*"semiconductor" + 0.008*"exciton"
# 2020-05-06 04:34:59,888 : INFO : topic #12 (0.048): 0.019*"semiconductor" + 0.013*"disorder" + 0.011*"model" + 0.011*"theory" + 0.008*"results" + 0.008*"semiconductors" + 0.006*"materials" + 0.006*"density" + 0.006*"power" + 0.006*"band"
# 2020-05-06 04:34:59,894 : INFO : topic diff=0.663886, rho=0.707107
# 2020-05-06 04:35:00,068 : INFO : -9.722 per-word bound, 844.5 perplexity estimate based on a held-out corpus of 222 documents with 8091 words
# 2020-05-06 04:35:00,068 : INFO : PROGRESS: pass 0, at document #4222/4222
# 2020-05-06 04:35:00,204 : INFO : merging changes from 222 documents into a model of 4222 documents
# 2020-05-06 04:35:00,217 : INFO : topic #2 (0.048): 0.037*"spin" + 0.037*"electron" + 0.023*"semiconductor" + 0.017*"transport" + 0.014*"effect" + 0.013*"quantum" + 0.012*"field" + 0.009*"equation" + 0.009*"equations" + 0.007*"properties"
# 2020-05-06 04:35:00,218 : INFO : topic #4 (0.048): 0.020*"spin" + 0.019*"quantum" + 0.018*"semiconductor" + 0.014*"field" + 0.013*"electron" + 0.013*"density" + 0.011*"function" + 0.010*"impurity" + 0.010*"system" + 0.009*"interaction"
# 2020-05-06 04:35:00,219 : INFO : topic #14 (0.048): 0.033*"field" + 0.017*"spin" + 0.013*"hole" + 0.011*"miniband" + 0.010*"electron" + 0.010*"fields" + 0.010*"electrons" + 0.010*"band" + 0.008*"superlattice" + 0.008*"semiconductors"
# 2020-05-06 04:35:00,222 : INFO : topic #19 (0.048): 0.047*"band" + 0.022*"semiconductors" + 0.015*"valence" + 0.014*"energy" + 0.014*"interface" + 0.012*"approximation" + 0.012*"model" + 0.011*"calculations" + 0.010*"GW" + 0.009*"function"
# 2020-05-06 04:35:00,223 : INFO : topic #18 (0.048): 0.021*"model" + 0.016*"solution" + 0.013*"solutions" + 0.013*"semiconductor" + 0.012*"energy" + 0.012*"field" + 0.011*"analysis" + 0.010*"domains" + 0.009*"Mn" + 0.008*"equations"
# 2020-05-06 04:35:00,225 : INFO : topic diff=0.629640, rho=0.577350
# 2020-05-06 04:35:02,843 : INFO : -8.688 per-word bound, 412.5 perplexity estimate based on a held-out corpus of 4222 documents with 189011 words
# 2020-05-06 04:35:02,849 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2020-05-06 04:35:06,668 : INFO : 3 accumulators retrieved from output queue
# 2020-05-06 04:35:06,709 : INFO : accumulated word occurrence stats for 4272 virtual documents
# 100%|██████████| 20/20 [03:20<00:00, 10.02s/it]

# %%
# evaluation
x = range(start, limit, step)
fig, ax1 = plt.subplots(figsize=(12,5))

# coherence
c1 = 'darkturquoise'
ax1.plot(x, coherence_vals, 'o-', color=c1)
ax1.set_xlabel('Num Topics')
ax1.set_ylabel('Coherence', color=c1); ax1.tick_params('y', colors=c1)

# perplexity
c2 = 'slategray'
ax2 = ax1.twinx()
ax2.plot(x, perplexity_vals, 'o-', color=c2)
ax2.set_ylabel('Perplexity', color=c2); ax2.tick_params('y', colors=c2)

# Vis
ax1.set_xticks(x)
fig.tight_layout()
plt.show()

# save as png
plt.savefig('metrics.png')

# %%
import logging
# LDA Model
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus, id2word=dictionary, num_topics=4, alpha='auto', random_state=0)
# Out:
# 2020-05-06 04:35:42,722 : INFO : using autotuned alpha, starting with [0.25, 0.25, 0.25, 0.25]
# 2020-05-06 04:35:42,724 : INFO : using symmetric eta at 0.25
# 2020-05-06 04:35:42,728 : INFO : using serial LDA version on this node
# 2020-05-06 04:35:42,740 : INFO : running online (single-pass) LDA training, 4 topics, 1 passes over the supplied corpus of 4222 documents, updating model once every 2000 documents, evaluating perplexity every 4222 documents, iterating 50x with a convergence threshold of 0.001000
# 2020-05-06 04:35:42,743 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2020-05-06 04:35:42,745 : INFO : PROGRESS: pass 0, at document #2000/4222
# 2020-05-06 04:35:44,314 : INFO : optimized alpha [0.22905178, 0.2909639, 0.2684713, 0.28934202]
# 2020-05-06 04:35:44,317 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:35:44,322 : INFO : topic #0 (0.229): 0.011*"semiconductor" + 0.008*"band" + 0.006*"states" + 0.006*"field" + 0.006*"results" + 0.006*"devices" + 0.006*"temperature" + 0.005*"materials" + 0.005*"electrons" + 0.005*"semiconductors"
# 2020-05-06 04:35:44,323 : INFO : topic #1 (0.291): 0.012*"semiconductor" + 0.011*"semiconductors" + 0.011*"quantum" + 0.011*"energy" + 0.008*"spin" + 0.008*"states" + 0.007*"band" + 0.006*"interaction" + 0.006*"properties" + 0.006*"charge"
# 2020-05-06 04:35:44,324 : INFO : topic #2 (0.268): 0.016*"semiconductor" + 0.011*"spin" + 0.011*"quantum" + 0.010*"properties" + 0.009*"transport" + 0.008*"electron" + 0.007*"semiconductors" + 0.007*"effect" + 0.007*"results" + 0.007*"field"
# 2020-05-06 04:35:44,326 : INFO : topic #3 (0.289): 0.011*"semiconductor" + 0.011*"model" + 0.010*"field" + 0.009*"band" + 0.009*"semiconductors" + 0.007*"properties" + 0.007*"materials" + 0.006*"structure" + 0.006*"phase" + 0.006*"temperature"
# 2020-05-06 04:35:44,326 : INFO : topic diff=3.072778, rho=1.000000
# 2020-05-06 04:35:44,329 : INFO : PROGRESS: pass 0, at document #4000/4222
# 2020-05-06 04:35:45,835 : INFO : optimized alpha [0.16894822, 0.27902043, 0.24541205, 0.27186516]
# 2020-05-06 04:35:45,839 : INFO : merging changes from 2000 documents into a model of 4222 documents
# 2020-05-06 04:35:45,843 : INFO : topic #0 (0.169): 0.014*"semiconductor" + 0.007*"field" + 0.007*"electrons" + 0.006*"states" + 0.006*"temperature" + 0.006*"band" + 0.006*"results" + 0.005*"energy" + 0.005*"model" + 0.005*"semiconductors"
# 2020-05-06 04:35:45,844 : INFO : topic #1 (0.279): 0.017*"quantum" + 0.015*"semiconductor" + 0.013*"spin" + 0.010*"semiconductors" + 0.010*"energy" + 0.010*"states" + 0.009*"interaction" + 0.006*"Mn" + 0.006*"coupling" + 0.006*"density"
# 2020-05-06 04:35:45,846 : INFO : topic #2 (0.245): 0.023*"spin" + 0.020*"semiconductor" + 0.014*"quantum" + 0.013*"electron" + 0.011*"transport" + 0.010*"effect" + 0.010*"field" + 0.007*"results" + 0.007*"properties" + 0.006*"semiconductors"
# 2020-05-06 04:35:45,847 : INFO : topic #3 (0.272): 0.014*"model" + 0.013*"field" + 0.012*"semiconductor" + 0.011*"semiconductors" + 0.010*"band" + 0.009*"temperature" + 0.008*"Mn" + 0.007*"theory" + 0.007*"structure" + 0.006*"results"
# 2020-05-06 04:35:45,848 : INFO : topic diff=1.067717, rho=0.707107
# 2020-05-06 04:35:46,063 : INFO : -7.933 per-word bound, 244.4 perplexity estimate based on a held-out corpus of 222 documents with 8091 words
# 2020-05-06 04:35:46,064 : INFO : PROGRESS: pass 0, at document #4222/4222
# 2020-05-06 04:35:46,231 : INFO : optimized alpha [0.14423034, 0.25036246, 0.1962616, 0.29410654]
# 2020-05-06 04:35:46,234 : INFO : merging changes from 222 documents into a model of 4222 documents
# 2020-05-06 04:35:46,239 : INFO : topic #0 (0.144): 0.013*"semiconductor" + 0.009*"states" + 0.009*"electrons" + 0.009*"field" + 0.007*"interface" + 0.007*"temperature" + 0.007*"emission" + 0.006*"band" + 0.006*"model" + 0.006*"conductance"
# 2020-05-06 04:35:46,241 : INFO : topic #1 (0.250): 0.025*"quantum" + 0.015*"semiconductor" + 0.011*"states" + 0.010*"interaction" + 0.010*"energy" + 0.010*"semiconductors" + 0.009*"spin" + 0.009*"density" + 0.006*"effects" + 0.006*"dots"
# 2020-05-06 04:35:46,242 : INFO : topic #2 (0.196): 0.022*"semiconductor" + 0.019*"spin" + 0.017*"electron" + 0.013*"quantum" + 0.011*"effect" + 0.010*"field" + 0.009*"transport" + 0.007*"results" + 0.006*"system" + 0.006*"temperature"
# 2020-05-06 04:35:46,244 : INFO : topic #3 (0.294): 0.016*"model" + 0.015*"field" + 0.012*"semiconductor" + 0.011*"semiconductors" + 0.011*"temperature" + 0.010*"band" + 0.009*"surface" + 0.008*"structure" + 0.007*"results" + 0.007*"theory"
# 2020-05-06 04:35:46,245 : INFO : topic diff=0.697955, rho=0.577350

# %%
import math
# WordCloud
fig, axs = plt.subplots(ncols=2, nrows=math.ceil(lda_model.num_topics/2), figsize=(16,20))
axs = axs.flatten()

def color_func(word, font_size, position, orientation, random_state, font_path):
    return 'darkturquoise'

for i, t in enumerate(range(lda_model.num_topics)):

    x = dict(lda_model.show_topic(t, 30))
    im = WordCloud(
        background_color='black',
        color_func=color_func,
        max_words=4000,
        width=300, height=300,
        random_state=0
    ).generate_from_frequencies(x)
    axs[i].imshow(im.recolor(colormap= 'Paired_r' , random_state=244), alpha=0.98)
    axs[i].axis('off')
    axs[i].set_title('Topic '+str(t))

# vis
plt.tight_layout()
plt.show()

# save as png
plt.savefig('wordcloud.png')

# %%
# pyLDAvis
import pyLDAvis
import pyLDAvis.gensim
pyLDAvis.enable_notebook()

# Vis PCoA
vis_pcoa = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary, sort_topics=False)
vis_pcoa

# save as html
pyLDAvis.save_html(vis_pcoa, '../html_pyldavis/pyldavis_output_pcoa.html')

# %%
# Vis Metric MDS
vis_mds = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary, mds='mmds', sort_topics=False)
vis_mds

# save as html
pyLDAvis.save_html(vis_mds, '../html_pyldavis/pyldavis_output_mds.html')
# Out:
# 2020-05-06 04:42:55,564 : WARNING : sklearn not present, switch to PCoA

# %%
# Vis t-SNE
vis_tsne = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary, mds='tsne', sort_topics=False)
vis_tsne

# save as html
pyLDAvis.save_html(vis_tsne, '../html_pyldavis/pyldavis_output_tsne.html')
# Out:
# 2020-05-06 04:43:11,585 : WARNING : sklearn not present, switch to PCoA
